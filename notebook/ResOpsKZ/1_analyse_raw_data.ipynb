# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
PATH = Path('Z:/nahaUsers/casadje/datasets/Kazakhstan/reservoirs')

# %%
reservoirs = pd.read_excel(
    PATH / 'reservoirs.xlsx',
    sheet_name='processed',
    index_col=0
)

reservoirs.head()
# Out:
#   Name of the structures  Branch Class  Water source Year of commissioning  \
# 1             Astana vdh  Akmola    II      R. Yesil                  1970
# 2        Seletinskoe vdh  Akmola    II     R. Selety                  1966
# 3       Chaglinskoye vdh  Akmola   III   R.Chaglinka                  1970
# 4       Koyandinskoe vdh  Akmola    IV    R. Koyandy                  1989
# 5      Krasnoborskoe vdh  Akmola    IV    R. Talkara                  1958
#
#    total volume effective volume  \
# 1         410.9            375.5
# 2         230.0          220,0,
# 3          28.0             27.2
# 4           5.8             5.16
# 5           6.7             2.25
#
#   Type of regulation and purpose (long-term, seasonal, standard, liquid)  \
# 1  Ruslovoe, long-term regulation, for water supp...
# 2  Industrial and household water supply in Stepn...
# 3  Water supply in Kokshetau, replenishment of th...
# 4                        Water source for irrigation
# 5  Reserve source of industrial water for the cit...
#
#    Capacity of the facility, m3/s Total area, ha Mirror area, km2  \
# 1                          1910.0           6070             60.7
# 2                          1740.0           3630             36.3
# 3                           680.0            660              6.6
# 4                            45.5            178             1.78
# 5                           115.0            410              4.1
#
#   Percentage of wear  Technical condition Paradise center (km)  \
# 1                 0.8        Satisfactory                   20
# 2                0.91        Satisfactory                   10
# 3                 0.3        Satisfactory                   12
# 4                0.29        Satisfactory                   50
# 5                0.08        Satisfactory                   40
#
#   The nearest settlement (km) longitude latitude  \
# 1                           5     72.06    50.59
# 2                           1     72.05    52.09
# 3                          12     69.15    53.16
# 4                           5     72.49    50.39
# 5                           2     71.41    51.19
#
#   Maximum depth according to the project, m  \
# 1                                        25
# 2                                        32
# 3                                        18
# 4                                        16
# 5                                         4
#
#    The year of acceptance on the balance sheet  \
# 1                                       1970.0
# 2                                       1966.0
# 3                                       2010.0
# 4                                       2002.0
# 5                                       2005.0
#
#   On the balance sheet (specify whose account)
# 1                             RSE "Kazvodkhoz"
# 2                             RSE "Kazvodkhoz"
# 3                             RSE "Kazvodkhoz"
# 4                             RSE "Kazvodkhoz"
# 5                             RSE "Kazvodkhoz"

# %%
{'Name of the structures': 'RES_NAME',
 'Branch',
 'Class',
 'Water source',
 'Year of commissioning': 'YEAR',
 'total volume': 'CAP_MCM',
 'effective volume',
 'Type of regulation and purpose (long-term, seasonal, standard, liquid)',
 'Capacity of the facility, m3/s', 'Total area, ha', 'Mirror area, km2',
 'Percentage of wear ', 
 'Technical condition', 
 'Paradise center (km)',
 'The nearest settlement (km)', 
 'longitude': 'LON', 
 'latitude': 'LAT',
 'Maximum depth according to the project, m': 'DEPTH_M',
 'The year of acceptance on the balance sheet',
 'On the balance sheet (specify whose account)'
}

# %%
reservoirs.columns
# Out:
# Index(['Name of the structures', 'Branch', 'Class', 'Water source',
#        'Year of commissioning', 'total volume', 'effective volume',
#        'Type of regulation and purpose (long-term, seasonal, standard, liquid)',
#        'Capacity of the facility, m3/s', 'Total area, ha', 'Mirror area, km2',
#        'Percentage of wear ', 'Technical condition', 'Paradise center (km)',
#        'The nearest settlement (km)', 'longitude', 'latitude',
#        'Maximum depth according to the project, m',
#        'The year of acceptance on the balance sheet',
#        'On the balance sheet (specify whose account)'],
#       dtype='object')
