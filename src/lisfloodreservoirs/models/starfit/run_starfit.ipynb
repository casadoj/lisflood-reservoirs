# %%
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
import pickle
import logging

from inputs import read_reservoir_attributes, read_reservoir_data
from starfit import Starfit

from lisfloodreservoirs.utils.metrics import KGEmod, compute_performance
from lisfloodreservoirs import Config, read_attributes, read_timeseries

# %% [markdown]
# ## Configuration

# %%
cfg = Config('Z:/nahaUsers/casadje/datasets/reservoirs/ResOpsUS/results/starfit/config_2var.yml')

# %% [markdown]
# ### Logger

# %%
# create logger
logger = logging.getLogger('simulate-starfit')
logger.setLevel(logging.INFO)
logger.propagate = False
log_format = logging.Formatter('%(asctime)s | %(levelname)s | %(name)s | %(message)s', datefmt='%Y-%m-%d %H:%M:%S')
# log on screen
c_handler = logging.StreamHandler()
c_handler.setFormatter(log_format)
c_handler.setLevel(logging.INFO)
logger.addHandler(c_handler)
# # log file
# log_path = cfg.PATH_CALIB / 'logs'
# log_path.mkdir(exist_ok=True)
# log_file = log_path / '{0:%Y%m%d%H%M}_calibrate_{1}.log'.format(datetime.now(),
#                                                                '_'.join(args.config_file.split('.')[0].split('_')[1:]))
# f_handler = logging.FileHandler(log_file)
# f_handler.setFormatter(log_format)
# f_handler.setLevel(logging.INFO)
# logger.addHandler(f_handler)

logger.info(f'Results will be saved in: {cfg.PATH_CALIB}')
# Out:
# 2024-07-31 12:42:01 | INFO | simulate-starfit | Results will be saved in: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsUS\results\starfit\calibration\bivariate

# %% [markdown]
# ## Data

# %% [markdown]
# ### Attributes

# %%
# list of reservoirs to be trained
try:
    reservoirs = pd.read_csv(cfg.RESERVOIRS_FILE, header=None).squeeze().tolist()
except IOError as e:
    logger.error(f'Failed to open {cfg.RESERVOIRS_FILE}: {e}')
    raise

# import all tables of attributes
try:
    attributes = read_attributes(cfg.PATH_DATA / 'attributes', reservoirs)
except IOError as e:
    logger.error('Failed to read attribute tables from {0}: {1}'.format(cfg.PATH_DATA / 'attributes', e))
    raise
logger.info(f'{attributes.shape[0]} reservoirs in the attribute tables')
# Out:
# 2024-07-31 12:42:02 | INFO | simulate-starfit | 90 reservoirs in the attribute tables

# %% [markdown]
# ### Time series

# %%
# training periods
try:
    with open(cfg.PERIODS_FILE, 'rb') as file:
        periods = pickle.load(file)
except IOError as e:
    logger.error(f'Failed to open {cfg.PERIODS_FILE}: {e}')
    raise

# read time series
try:
    timeseries = read_timeseries(cfg.PATH_DATA / 'time_series' / 'csv',
                                 attributes.index,
                                 periods)
except IOError as e:
    logger.error('Failed to read time series from {0}: {1}'.format(cfg.PATH_DATA / 'time_series' / 'csv', e))
    raise
logger.info(f'{len(timeseries)} reservoirs with timeseries')
# Out:
# 2024-07-31 12:42:06 | INFO | simulate-starfit | 90 reservoirs with timeseries

# %% [markdown]
# ## Class

# %%
for grand_id, obs in tqdm(timeseries.items(), desc='simulating reservoir'):
        
    # add day of the year to the observed time series
    obs['doy'] = obs.index.dayofyear   

    # SIMULTE OPTIMIZED RESERVOIR
    
    try:
        
        # load fitted storage model
        # model_storage = pd.read_csv(cfg.PATH_DEF.parent / 'NOR' / f'{grand_id}.csv')
        with open(cfg.PATH_DEF.parent / 'NOR' / f'{grand_id}.pkl', 'rb') as file:
            model_storage = pickle.load(file)
        NOR = pd.DataFrame({
                'flood': model_storage["NOR upper bound"],
                'conservation': model_storage["NOR lower bound"]
            })
        Vtot = model_storage['capacity (MCM)'] * 1e6
        
        # load fitted release model
        with open(cfg.PATH_DEF.parent / 'release' / f'{grand_id}.pkl', 'rb') as file:
            model_release = pickle.load(file)
        avg_inflow = model_release['mean inflow (MCM/wk)'] * 1e6 / (7 * 86400) # m3/s
        Qmin, Qmax = (model_release['constraints'] + 1) * avg_inflow

        # declare reservoir
        res = Starfit(Vtot=Vtot,
                      avg_inflow=avg_inflow,
                      pars_Vf=NOR['flood'],
                      pars_Vc=NOR['conservation'],
                      pars_Qharm=model_release['harmonic parameters'],
                      pars_Qresid=model_release['residual parameters'],
                      Qmin=Qmin,
                      Qmax=Qmax)
        
        # export calibrated parameters
        # with open(cfg.PATH_CALIB / f'{grand_id}_optimal_parameters.yml', 'w') as file:
        #     yaml.dump(res.get_params(), file)
        
        # simulate
        sim = res.simulate(obs.inflow, obs.storage.iloc[0])
        sim.to_csv(cfg.PATH_CALIB / f'{grand_id}_simulation.csv', float_format='%.3f')
        
        logger.info(f'Simulation of the calibrated reservoir {grand_id} successfully finished')
        
    except RuntimeError as e:
        logger.error(f'Calibrated reservoir {grand_id} could not be simulated: {e}')
        continue

    # ANALYSE RESULTS

    # performance
    try:
        performance_cal = compute_performance(obs, sim)
        performance_cal.to_csv(cfg.PATH_CALIB / f'{grand_id}_performance.csv', float_format='%.3f')
        logger.info(f'Performance of reservoir {grand_id} has been computed')
    except IOError as e:
        logger.error(f'The performance of reservoir {grand_id} could not be exported: {e}')

    # scatter plot simulation vs observation
    try:
        res.scatter(sim,
                    obs,
                    norm=False,
                    title=f'grand_id: {grand_id}',
                    save=cfg.PATH_CALIB / f'{grand_id}_scatter.jpg',
                   )
        logger.info(f'Scatter plot of simulation from reservoir {grand_id}')
    except IOError as e:
        logger.error(f'The scatter plot of reservoir {grand_id} could not be generated: {e}')

    # line plot calibration (vs default simulation) vs observation
    try:
        res.lineplot({'starfit': sim},
                     obs, 
                     Vlims=[res.Vtot],
                     Qlims=[res.Qmin, res.Qmax],
                     figsize=(12, 6),
                     save=cfg.PATH_CALIB / f'{grand_id}_line.jpg',
                   )
        logger.info(f'Line plot of simulation from reservoir {grand_id}')
    except IOError as e:
        logger.error(f'The line plot of reservoir {grand_id} could not be generated: {e}')
# Out:
# simulating reservoir:   0%|          | 0/90 [00:00<?, ?it/s]
# 2024-07-31 12:42:36 | INFO | simulate-starfit | Simulation of the calibrated reservoir 41 successfully finished
# 2024-07-31 12:42:36 | INFO | simulate-starfit | Performance of reservoir 41 has been computed
# 2024-07-31 12:42:37 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 41
# 2024-07-31 12:42:37 | INFO | simulate-starfit | Line plot of simulation from reservoir 41
# 2024-07-31 12:42:43 | INFO | simulate-starfit | Simulation of the calibrated reservoir 63 successfully finished
# 2024-07-31 12:42:43 | INFO | simulate-starfit | Performance of reservoir 63 has been computed
# 2024-07-31 12:42:44 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 63
# 2024-07-31 12:42:44 | INFO | simulate-starfit | Line plot of simulation from reservoir 63
# 2024-07-31 12:42:46 | INFO | simulate-starfit | Simulation of the calibrated reservoir 293 successfully finished
# 2024-07-31 12:42:46 | INFO | simulate-starfit | Performance of reservoir 293 has been computed
# 2024-07-31 12:42:47 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 293
# 2024-07-31 12:42:47 | INFO | simulate-starfit | Line plot of simulation from reservoir 293
# 2024-07-31 12:42:49 | INFO | simulate-starfit | Simulation of the calibrated reservoir 300 successfully finished
# 2024-07-31 12:42:49 | INFO | simulate-starfit | Performance of reservoir 300 has been computed
# 2024-07-31 12:42:50 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 300
# 2024-07-31 12:42:50 | INFO | simulate-starfit | Line plot of simulation from reservoir 300
# 2024-07-31 12:42:53 | INFO | simulate-starfit | Simulation of the calibrated reservoir 307 successfully finished
# 2024-07-31 12:42:53 | INFO | simulate-starfit | Performance of reservoir 307 has been computed
# 2024-07-31 12:42:54 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 307
# 2024-07-31 12:42:55 | INFO | simulate-starfit | Line plot of simulation from reservoir 307
# 2024-07-31 12:42:59 | INFO | simulate-starfit | Simulation of the calibrated reservoir 319 successfully finished
# 2024-07-31 12:42:59 | INFO | simulate-starfit | Performance of reservoir 319 has been computed
# 2024-07-31 12:43:00 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 319
# 2024-07-31 12:43:00 | INFO | simulate-starfit | Line plot of simulation from reservoir 319
# 2024-07-31 12:43:06 | INFO | simulate-starfit | Simulation of the calibrated reservoir 355 successfully finished
# 2024-07-31 12:43:06 | INFO | simulate-starfit | Performance of reservoir 355 has been computed
# 2024-07-31 12:43:07 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 355
# 2024-07-31 12:43:08 | INFO | simulate-starfit | Line plot of simulation from reservoir 355
# 2024-07-31 12:43:13 | INFO | simulate-starfit | Simulation of the calibrated reservoir 362 successfully finished
# 2024-07-31 12:43:13 | INFO | simulate-starfit | Performance of reservoir 362 has been computed
# 2024-07-31 12:43:14 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 362
# 2024-07-31 12:43:15 | INFO | simulate-starfit | Line plot of simulation from reservoir 362
# 2024-07-31 12:43:19 | INFO | simulate-starfit | Simulation of the calibrated reservoir 364 successfully finished
# 2024-07-31 12:43:19 | INFO | simulate-starfit | Performance of reservoir 364 has been computed
# 2024-07-31 12:43:19 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 364
# 2024-07-31 12:43:20 | INFO | simulate-starfit | Line plot of simulation from reservoir 364
# 2024-07-31 12:43:21 | INFO | simulate-starfit | Simulation of the calibrated reservoir 367 successfully finished
# 2024-07-31 12:43:21 | INFO | simulate-starfit | Performance of reservoir 367 has been computed
# 2024-07-31 12:43:22 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 367
# 2024-07-31 12:43:22 | INFO | simulate-starfit | Line plot of simulation from reservoir 367
# 2024-07-31 12:43:24 | INFO | simulate-starfit | Simulation of the calibrated reservoir 368 successfully finished
# 2024-07-31 12:43:24 | INFO | simulate-starfit | Performance of reservoir 368 has been computed
# 2024-07-31 12:43:25 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 368
# 2024-07-31 12:43:25 | INFO | simulate-starfit | Line plot of simulation from reservoir 368
# 2024-07-31 12:43:27 | INFO | simulate-starfit | Simulation of the calibrated reservoir 372 successfully finished
# 2024-07-31 12:43:27 | INFO | simulate-starfit | Performance of reservoir 372 has been computed
# 2024-07-31 12:43:28 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 372
# 2024-07-31 12:43:28 | INFO | simulate-starfit | Line plot of simulation from reservoir 372
# 2024-07-31 12:43:34 | INFO | simulate-starfit | Simulation of the calibrated reservoir 373 successfully finished
# 2024-07-31 12:43:34 | INFO | simulate-starfit | Performance of reservoir 373 has been computed
# 2024-07-31 12:43:35 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 373
# 2024-07-31 12:43:36 | INFO | simulate-starfit | Line plot of simulation from reservoir 373
# 2024-07-31 12:43:42 | INFO | simulate-starfit | Simulation of the calibrated reservoir 384 successfully finished
# 2024-07-31 12:43:42 | INFO | simulate-starfit | Performance of reservoir 384 has been computed
# 2024-07-31 12:43:43 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 384
# 2024-07-31 12:43:44 | INFO | simulate-starfit | Line plot of simulation from reservoir 384
# 2024-07-31 12:43:46 | INFO | simulate-starfit | Simulation of the calibrated reservoir 391 successfully finished
# 2024-07-31 12:43:46 | INFO | simulate-starfit | Performance of reservoir 391 has been computed
# 2024-07-31 12:43:46 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 391
# 2024-07-31 12:43:47 | INFO | simulate-starfit | Line plot of simulation from reservoir 391
# 2024-07-31 12:43:53 | INFO | simulate-starfit | Simulation of the calibrated reservoir 393 successfully finished
# 2024-07-31 12:43:53 | INFO | simulate-starfit | Performance of reservoir 393 has been computed
# 2024-07-31 12:43:54 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 393
# 2024-07-31 12:43:54 | INFO | simulate-starfit | Line plot of simulation from reservoir 393
# 2024-07-31 12:44:00 | INFO | simulate-starfit | Simulation of the calibrated reservoir 398 successfully finished
# 2024-07-31 12:44:00 | INFO | simulate-starfit | Performance of reservoir 398 has been computed
# 2024-07-31 12:44:01 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 398
# 2024-07-31 12:44:02 | INFO | simulate-starfit | Line plot of simulation from reservoir 398
# 2024-07-31 12:44:06 | INFO | simulate-starfit | Simulation of the calibrated reservoir 416 successfully finished
# 2024-07-31 12:44:06 | INFO | simulate-starfit | Performance of reservoir 416 has been computed
# 2024-07-31 12:44:06 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 416
# 2024-07-31 12:44:07 | INFO | simulate-starfit | Line plot of simulation from reservoir 416
# 2024-07-31 12:44:08 | INFO | simulate-starfit | Simulation of the calibrated reservoir 419 successfully finished
# 2024-07-31 12:44:08 | INFO | simulate-starfit | Performance of reservoir 419 has been computed
# 2024-07-31 12:44:09 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 419
# 2024-07-31 12:44:10 | INFO | simulate-starfit | Line plot of simulation from reservoir 419
# 2024-07-31 12:44:15 | INFO | simulate-starfit | Simulation of the calibrated reservoir 421 successfully finished
# 2024-07-31 12:44:15 | INFO | simulate-starfit | Performance of reservoir 421 has been computed
# 2024-07-31 12:44:16 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 421
# 2024-07-31 12:44:17 | INFO | simulate-starfit | Line plot of simulation from reservoir 421
# 2024-07-31 12:44:21 | INFO | simulate-starfit | Simulation of the calibrated reservoir 423 successfully finished
# 2024-07-31 12:44:21 | INFO | simulate-starfit | Performance of reservoir 423 has been computed
# 2024-07-31 12:44:22 | INFO | simulate-starfit | Scatter plot of simulation from reservoir
| INFO | simulate-starfit | Scatter plot of simulation from reservoir 488
# 2024-07-31 12:45:05 | INFO | simulate-starfit | Line plot of simulation from reservoir 488
# 2024-07-31 12:45:11 | INFO | simulate-starfit | Simulation of the calibrated reservoir 497 successfully finished
# 2024-07-31 12:45:11 | INFO | simulate-starfit | Performance of reservoir 497 has been computed
# 2024-07-31 12:45:12 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 497
# 2024-07-31 12:45:12 | INFO | simulate-starfit | Line plot of simulation from reservoir 497
# 2024-07-31 12:45:16 | INFO | simulate-starfit | Simulation of the calibrated reservoir 502 successfully finished
# 2024-07-31 12:45:16 | INFO | simulate-starfit | Performance of reservoir 502 has been computed
# 2024-07-31 12:45:17 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 502
# 2024-07-31 12:45:17 | INFO | simulate-starfit | Line plot of simulation from reservoir 502
# 2024-07-31 12:45:20 | INFO | simulate-starfit | Simulation of the calibrated reservoir 511 successfully finished
# 2024-07-31 12:45:20 | INFO | simulate-starfit | Performance of reservoir 511 has been computed
# 2024-07-31 12:45:21 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 511
# 2024-07-31 12:45:21 | INFO | simulate-starfit | Line plot of simulation from reservoir 511
# 2024-07-31 12:45:25 | INFO | simulate-starfit | Simulation of the calibrated reservoir 517 successfully finished
# 2024-07-31 12:45:25 | INFO | simulate-starfit | Performance of reservoir 517 has been computed
# 2024-07-31 12:45:26 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 517
# 2024-07-31 12:45:26 | INFO | simulate-starfit | Line plot of simulation from reservoir 517
# 2024-07-31 12:45:28 | INFO | simulate-starfit | Simulation of the calibrated reservoir 518 successfully finished
# 2024-07-31 12:45:28 | INFO | simulate-starfit | Performance of reservoir 518 has been computed
# 2024-07-31 12:45:29 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 518
# 2024-07-31 12:45:29 | INFO | simulate-starfit | Line plot of simulation from reservoir 518
# 2024-07-31 12:45:32 | INFO | simulate-starfit | Simulation of the calibrated reservoir 522 successfully finished
# 2024-07-31 12:45:32 | INFO | simulate-starfit | Performance of reservoir 522 has been computed
# 2024-07-31 12:45:33 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 522
# 2024-07-31 12:45:33 | INFO | simulate-starfit | Line plot of simulation from reservoir 522
# 2024-07-31 12:45:38 | INFO | simulate-starfit | Simulation of the calibrated reservoir 530 successfully finished
# 2024-07-31 12:45:38 | INFO | simulate-starfit | Performance of reservoir 530 has been computed
# 2024-07-31 12:45:39 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 530
# 2024-07-31 12:45:40 | INFO | simulate-starfit | Line plot of simulation from reservoir 530
# 2024-07-31 12:45:44 | INFO | simulate-starfit | Simulation of the calibrated reservoir 533 successfully finished
# 2024-07-31 12:45:44 | INFO | simulate-starfit | Performance of reservoir 533 has been computed
# 2024-07-31 12:45:45 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 533
# 2024-07-31 12:45:45 | INFO | simulate-starfit | Line plot of simulation from reservoir 533
# 2024-07-31 12:45:48 | INFO | simulate-starfit | Simulation of the calibrated reservoir 536 successfully finished
# 2024-07-31 12:45:48 | INFO | simulate-starfit | Performance of reservoir 536 has been computed
# 2024-07-31 12:45:49 | INFO | simulate-starfit | Scatter plot of simulation from reservoir
| INFO | simulate-starfit | Scatter plot of simulation from reservoir 1796
# 2024-07-31 12:49:36 | INFO | simulate-starfit | Line plot of simulation from reservoir 1796
# 2024-07-31 12:49:42 | INFO | simulate-starfit | Simulation of the calibrated reservoir 1848 successfully finished
# 2024-07-31 12:49:42 | INFO | simulate-starfit | Performance of reservoir 1848 has been computed
# 2024-07-31 12:49:43 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 1848
# 2024-07-31 12:49:43 | INFO | simulate-starfit | Line plot of simulation from reservoir 1848
# 2024-07-31 12:49:49 | INFO | simulate-starfit | Simulation of the calibrated reservoir 1851 successfully finished
# 2024-07-31 12:49:49 | INFO | simulate-starfit | Performance of reservoir 1851 has been computed
# 2024-07-31 12:49:50 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 1851
# 2024-07-31 12:49:51 | INFO | simulate-starfit | Line plot of simulation from reservoir 1851
# 2024-07-31 12:49:54 | INFO | simulate-starfit | Simulation of the calibrated reservoir 1864 successfully finished
# 2024-07-31 12:49:54 | INFO | simulate-starfit | Performance of reservoir 1864 has been computed
# 2024-07-31 12:49:55 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 1864
# 2024-07-31 12:49:55 | INFO | simulate-starfit | Line plot of simulation from reservoir 1864
# 2024-07-31 12:50:00 | INFO | simulate-starfit | Simulation of the calibrated reservoir 1872 successfully finished
# 2024-07-31 12:50:00 | INFO | simulate-starfit | Performance of reservoir 1872 has been computed
# 2024-07-31 12:50:01 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 1872
# 2024-07-31 12:50:02 | INFO | simulate-starfit | Line plot of simulation from reservoir 1872
# 2024-07-31 12:50:03 | INFO | simulate-starfit | Simulation of the calibrated reservoir 1910 successfully finished
# 2024-07-31 12:50:03 | INFO | simulate-starfit | Performance of reservoir 1910 has been computed
# 2024-07-31 12:50:04 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 1910
# 2024-07-31 12:50:05 | INFO | simulate-starfit | Line plot of simulation from reservoir 1910
# 2024-07-31 12:50:09 | INFO | simulate-starfit | Simulation of the calibrated reservoir 7308 successfully finished
# 2024-07-31 12:50:09 | INFO | simulate-starfit | Performance of reservoir 7308 has been computed
# 2024-07-31 12:50:10 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 7308
# 2024-07-31 12:50:11 | INFO | simulate-starfit | Line plot of simulation from reservoir 7308
# 2024-07-31 12:50:16 | INFO | simulate-starfit | Simulation of the calibrated reservoir 7313 successfully finished
# 2024-07-31 12:50:16 | INFO | simulate-starfit | Performance of reservoir 7313 has been computed
# 2024-07-31 12:50:17 | INFO | simulate-starfit | Scatter plot of simulation from reservoir 7313
# 2024-07-31 12:50:18 | INFO | simulate-starfit | Line plot of simulation from reservoir 7313

# %%
# obs = timeseries[362]

# sim = res.simulate(obs.inflow, obs.storage.iloc[0])
# sim['doy'] = sim.index.dayofweek
# sim = sim.reset_index().merge(res.NOR * res.Vtot, on='doy').merge(res.avg_inflow * (res.Qharm + 1), on='doy').set_index('date')
# sim.sort_index(inplace=True)

# %%
# res.lineplot({'starfit': sim},
#                      obs, 
#                      Vlims=[res.Vtot],
#                      Qlims=[res.Qmin, res.Qmax],
#                      figsize=(12, 6),
#                      save=None,
#              xlim=('1996-01-01', '1997-01-01')
#             )

# %%
# fig, ax = plt.subplots(nrows=2, figsize=(12, 8), sharex=True)

# sim.loc['1995-10-15':'1995-11-01', ['storage', 'flood']].plot(ax=ax[0]);

# sim.loc['1995-10-15':'1995-11-01', ['inflow', 'outflow', 'release']].plot(ax=ax[1])
# ax[1].axhline(res.Qmax, ls=':', color='k')
# ;
