# %%
# import numpy as np
import pandas as pd
from pathlib import Path
from tqdm.auto import tqdm
# import matplotlib.pyplot as plt
import pickle
import logging

from inputs import read_reservoir_attributes, read_reservoir_data
from starfit import Starfit

from lisfloodreservoirs.utils.metrics import KGEmod, compute_performance
from lisfloodreservoirs import Config, read_attributes, read_timeseries

# %% [markdown]
# ## Configuration

# %%
config_file = 'Z:/nahaUsers/casadje/datasets/reservoirs/ResOpsUS/v2.0/results/starfit/config.yml'
cfg = Config(config_file)

# %% [markdown]
# ### Logger

# %%
# set up root logger
root_logger = logging.getLogger()
root_logger.setLevel(logging.INFO)

# define format
log_format = logging.Formatter('%(asctime)s | %(levelname)s | %(name)s | %(message)s',
                               datefmt='%Y-%m-%d %H:%M:%S')

# # define log file
# log_path = cfg.PATH_CALIB / 'logs'
# log_path.mkdir(exist_ok=True)
# log_file = log_path / '{0:%Y%m%d%H%M}_calibrate_{1}.log'.format(
#     datetime.now(),
#     '_'.join(config_file.split('.')[0].split('_')[1:]))

# prevent duplicate logs in Jupyter or re-runs
if not root_logger.handlers:
    # console handler
    c_handler = logging.StreamHandler()
    c_handler.setFormatter(log_format)
    root_logger.addHandler(c_handler)

    # # file handler
    # f_handler = logging.FileHandler(log_file)
    # f_handler.setFormatter(log_format)
    # root_logger.addHandler(f_handler)

# create a named logger for this script
logger = logging.getLogger('run-starfit')

# %%
logger.info(f'Results will be saved in: {cfg.PATH_CALIB}')
# Out:
# 2025-04-10 16:31:58 | INFO | run-starfit | Results will be saved in: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsUS\v2.0\results\starfit\calibration\bivariate

# %% [markdown]
# ## Data

# %%
# list of reservoirs to be trained
try:
    reservoirs = pd.read_csv(cfg.RESERVOIRS_FILE, header=None).squeeze().tolist()
except IOError as e:
    logger.error(f'Failed to open {cfg.RESERVOIRS_FILE}: {e}')
    raise

# import all tables of attributes
try:
    attributes = read_attributes(cfg.PATH_DATA / 'attributes', reservoirs)
except IOError as e:
    logger.error('Failed to read attribute tables from {0}: {1}'.format(cfg.PATH_DATA / 'attributes', e))
    raise
logger.info(f'{attributes.shape[0]} reservoirs in the attribute tables')
# Out:
# 2025-04-10 16:31:58 | INFO | run-starfit | 123 reservoirs in the attribute tables

# %%
# training periods
try:
    with open(cfg.PERIODS_FILE, 'rb') as file:
        periods = pickle.load(file)
except IOError as e:
    logger.error(f'Failed to open {cfg.PERIODS_FILE}: {e}')
    raise

# read time series
try:
    timeseries = read_timeseries(cfg.PATH_DATA / 'time_series' / 'csv',
                                 attributes.index,
                                 periods)
except IOError as e:
    logger.error('Failed to read time series from {0}: {1}'.format(cfg.PATH_DATA / 'time_series' / 'csv', e))
    raise
logger.info(f'{len(timeseries)} reservoirs with timeseries')
# Out:
# 2025-04-10 16:32:10 | INFO | run-starfit | 123 reservoirs with timeseries

# %% [markdown]
# ## Run

# %%
for grand_id, obs in tqdm(timeseries.items(), desc='simulating reservoir'):

    logger.info(f'Simulating reservoir {grand_id}')
    # add day of the year to the observed time series
    obs['doy'] = obs.index.dayofyear

    # SIMULTE OPTIMIZED RESERVOIR

    # load fitted storage model
    try:
        with open(cfg.PATH_DEF.parent / 'NOR' / f'{grand_id}.pkl', 'rb') as file:
            model_storage = pickle.load(file)
        NOR = pd.DataFrame({
                'flood': model_storage["NOR upper bound"],
                'conservation': model_storage["NOR lower bound"]
            })
        Vtot = model_storage['capacity (MCM)'] * 1e6
        logger.debug('Storage model correctly loaded')
    except Exception as e:
        logger.error(f'Storage modeld could not be loaded: {e}')
        continue
        
    # load fitted release model
    try:
        with open(cfg.PATH_DEF.parent / 'release' / f'{grand_id}.pkl', 'rb') as file:
            model_release = pickle.load(file)
        avg_inflow = model_release['mean inflow (MCM/wk)'] * 1e6 / (7 * 86400) # m3/s
        Qmin, Qmax = (model_release['constraints'] + 1) * avg_inflow
        logger.debug('Release model correctly loaded')
    except Exception as e:
        logger.error(f'Release model could not be loaded: {e}')
        continue

    # declare reservoir
    try:
        res = Starfit(
            Vtot=Vtot,
            avg_inflow=avg_inflow,
            pars_Vf=NOR['flood'],
            pars_Vc=NOR['conservation'],
            pars_Qharm=model_release['harmonic parameters'],
            pars_Qresid=model_release['residual parameters'],
            Qmin=Qmin,
            Qmax=Qmax
        )
        # export calibrated parameters
        # TODO: `get_params()` not implemented in class `Starfit`
        # with open(cfg.PATH_CALIB / f'{grand_id}_optimal_parameters.yml', 'w') as file:
        #     yaml.dump(res.get_params(), file)
        logger.debug('Starfit class correctly declared')
    except Exception as e:
        logger.error(f'Starfit class could not be declared: {e}')
        continue

    # run simulation
    try:
        sim = res.simulate(obs.inflow, obs.storage.iloc[0])
        sim.to_csv(cfg.PATH_CALIB / f'{grand_id}_simulation.csv', float_format='%.3f')
        logger.info('Simulation successfully finished')
    except RuntimeError as e:
        logger.error(f'The simulation crashed: {e}')
        continue

    # ANALYSE RESULTS

    # performance
    try:
        performance_cal = compute_performance(obs, sim)
        performance_cal.to_csv(cfg.PATH_CALIB / f'{grand_id}_performance.csv', float_format='%.3f')
        logger.info(f'Performance of reservoir {grand_id} has been computed')
    except IOError as e:
        logger.error(f'The performance of reservoir {grand_id} could not be exported: {e}')

    # scatter plot simulation vs observation
    try:
        res.scatter(
            sim,
            obs,
            norm=False,
            title=f'grand_id: {grand_id}',
            save=cfg.PATH_CALIB / f'{grand_id}_scatter.jpg',
            )
        logger.debug('Scatter plot of simulation successfully created')
    except IOError as e:
        logger.error(f'The scatter plot of reservoir {grand_id} could not be generated: {e}')

    # line plot calibration (vs default simulation) vs observation
    try:
        res.lineplot(
            {'starfit': sim},
            obs, 
            Vlims=[res.Vtot],
            Qlims=[res.Qmin, res.Qmax],
            figsize=(12, 6),
            save=cfg.PATH_CALIB / f'{grand_id}_line.jpg',
            )
        logger.debug(f'Line plot of simulation successfully created')
    except IOError as e:
        logger.error(f'The line plot of reservoir {grand_id} could not be generated: {e}')
# Out:
# simulating reservoir:   0%|          | 0/123 [00:00<?, ?it/s]
# 2025-04-10 16:50:27 | INFO | run-starfit | Simulating reservoir 41
# 2025-04-10 16:50:29 | INFO | run-starfit | Simulation of the calibrated reservoir 41 successfully finished
# 2025-04-10 16:50:29 | INFO | run-starfit | Performance of reservoir 41 has been computed
# 2025-04-10 16:50:30 | INFO | run-starfit | Scatter plot of simulation from reservoir 41
# 2025-04-10 16:50:30 | INFO | run-starfit | Line plot of simulation from reservoir 41
# 2025-04-10 16:50:30 | INFO | run-starfit | Simulating reservoir 63
# 2025-04-10 16:50:34 | INFO | run-starfit | Simulation of the calibrated reservoir 63 successfully finished
# 2025-04-10 16:50:34 | INFO | run-starfit | Performance of reservoir 63 has been computed
# 2025-04-10 16:50:35 | INFO | run-starfit | Scatter plot of simulation from reservoir 63
# 2025-04-10 16:50:35 | INFO | run-starfit | Line plot of simulation from reservoir 63
# 2025-04-10 16:50:35 | INFO | run-starfit | Simulating reservoir 131
# 2025-04-10 16:50:36 | INFO | run-starfit | Simulation of the calibrated reservoir 131 successfully finished
# 2025-04-10 16:50:36 | INFO | run-starfit | Performance of reservoir 131 has been computed
# 2025-04-10 16:50:37 | INFO | run-starfit | Scatter plot of simulation from reservoir 131
# 2025-04-10 16:50:37 | INFO | run-starfit | Line plot of simulation from reservoir 131
# 2025-04-10 16:50:37 | INFO | run-starfit | Simulating reservoir 132
# 2025-04-10 16:50:37 | INFO | run-starfit | Simulation of the calibrated reservoir 132 successfully finished
# 2025-04-10 16:50:38 | INFO | run-starfit | Performance of reservoir 132 has been computed
# 2025-04-10 16:50:38 | INFO | run-starfit | Scatter plot of simulation from reservoir 132
# 2025-04-10 16:50:38 | INFO | run-starfit | Line plot of simulation from reservoir 132
# 2025-04-10 16:50:38 | INFO | run-starfit | Simulating reservoir 133
# 2025-04-10 16:50:39 | INFO | run-starfit | Simulation of the calibrated reservoir 133 successfully finished
# 2025-04-10 16:50:39 | INFO | run-starfit | Performance of reservoir 133 has been computed
# 2025-04-10 16:50:39 | INFO | run-starfit | Scatter plot of simulation from reservoir 133
# 2025-04-10 16:50:40 | INFO | run-starfit | Line plot of simulation from reservoir 133
# 2025-04-10 16:50:40 | INFO | run-starfit | Simulating reservoir 182
# 2025-04-10 16:50:40 | INFO | run-starfit | Simulation of the calibrated reservoir 182 successfully finished
# 2025-04-10 16:50:40 | INFO | run-starfit | Performance of reservoir 182 has been computed
# 2025-04-10 16:50:41 | INFO | run-starfit | Scatter plot of simulation from reservoir 182
# 2025-04-10 16:50:41 | INFO | run-starfit | Line plot of simulation from reservoir 182
# 2025-04-10 16:50:41 | INFO | run-starfit | Simulating reservoir 198
# 2025-04-10 16:50:42 | INFO | run-starfit | Simulation of the calibrated reservoir 198 successfully finished
# 2025-04-10 16:50:42 | INFO | run-starfit | Performance of reservoir 198 has been computed
# 2025-04-10 16:50:42 | INFO | run-starfit | Scatter plot of simulation from reservoir 198
# 2025-04-10 16:50:43 | INFO | run-starfit | Line plot of simulation from reservoir 198
# 2025-04-10 16:50:43 | INFO | run-starfit | Simulating reservoir 293
# 2025-04-10 16:50:44 | INFO | run-starfit | Simulation of the calibrated reservoir 293 successfully finished
# 2025-04-10 16:50:44 | INFO | run-starfit | Performance of reservoir 293 has been computed
# 2025-04-10 16:50:45 | INFO | run-starfit | Scatter plot of simulation from reservoir 293
# 2025-04-10 16:50:45 | INFO | run-starfit | Line plot of simulation from reservoir 293
# 2025-04-10 16:50:45 | INFO | run-starfit | Simulating reservoir 297
# 2025-04-10 16:50:45 | INFO | run-starfit | Simulation of the calibrated reservoir 297 successfully finished
# 2025-04-10 16:50:45 | INFO | run-starfit | Performance of reservoir 297 has been computed
# 2025-04-10 16:50:46 | INFO | run-starfit | Scatter plot of simulation from reservoir 297
# 2025-04-10 16:50:46 | INFO | run-starfit | Line plot of simulation from reservoir 297
# 2025-04-10 16:50:46 | INFO | run-starfit | Simulating reservoir 300
# 2025-04-10 16:50:48 | INFO | run-starfit | Simulation of the calibrated reservoir 300 successfully finished
# 2025-04-10 16:50:48 | INFO | run-starfit | Performance of reservoir 300 has been computed
# 2025-04-10 16:50:48 | INFO | run-starfit | Scatter plot of simulation from reservoir 300
# 2025-04-10 16:50:49 | INFO | run-starfit | Line plot of simulation from reservoir 300
# 2025-04-10 16:50:49 | INFO | run-starfit | Simulating reservoir 307
# 2025-04-10 16:50:51 | INFO | run-starfit | Simulation of the calibrated reservoir 307 successfully finished
# 2025-04-10 16:50:51 | INFO | run-starfit | Performance of reservoir 307 has been computed
# 2025-04-10 16:50:52 | INFO | run-starfit | Scatter plot of simulation from reservoir 307
# 2025-04-10 16:50:52 | INFO | run-starfit | Line plot of simulation from reservoir 307
# 2025-04-10 16:50:52 | INFO | run-starfit | Simulating reservoir 319
# 2025-04-10 16:50:55 | INFO | run-starfit | Simulation of the calibrated reservoir 319 successfully finished
# 2025-04-10 16:50:55 | INFO | run-starfit | Performance of reservoir 319 has been computed
# 2025-04-10 16:50:56 | INFO | run-starfit | Scatter plot of simulation from reservoir 319
# 2025-04-10 16:50:56 | INFO | run-starfit | Line plot of simulation from reservoir 319
# 2025-04-10 16:50:56 | INFO | run-starfit | Simulating reservoir 355
# 2025-04-10 16:51:00 | INFO | run-starfit | Simulation of the calibrated reservoir 355 successfully finished
# 2025-04-10 16:51:00 | INFO | run-starfit | Performance of reservoir 355 has been computed
# 2025-04-10 16:51:01 | INFO | run-starfit | Scatter plot of simulation from reservoir 355
# 2025-04-10 16:51:01 | INFO | run-starfit | Line plot of simulation from reservoir 355
# 2025-04-10 16:51:01 | INFO | run-starfit | Simulating reservoir 361
# 2025-04-10 16:51:02 | INFO | run-starfit | Simulation of the calibrated reservoir 361 successfully finished
# 2025-04-10 16:51:02 | INFO | run-starfit | Performance of reservoir 361 has been computed
# 2025-04-10 16:51:03 | INFO | run-starfit | Scatter plot of simulation from reservoir 361
# 2025-04-10 16:51:03 | INFO | run-starfit | Line plot of simulation from reservoir 361
# 2025-04-10 16:51:03 | INFO | run-starfit | Simulating reservoir 362
# 2025-04-10 16:51:07 | INFO | run-starfit | Simulation of the calibrated reservoir 362 successfully finished
# 2025-04-10 16:51:07 | INFO | run-starfit | Performance of reservoir 362 has been computed
# 2025-04-10 16:51:08 | INFO | run-starfit | Scatter plot of simulation from reservoir 362
# 2025-04-10 16:51:08 | INFO | run-starfit | Line plot of simulation from reservoir 362
# 2025-04-10 16:51:08 | INFO | run-starfit | Simulating reservoir 364
# 2025-04-10 16:51:11 | INFO | run-starfit | Simulation of the calibrated reservoir 364 successfully finished
# 2025-04-10 16:51:11 | INFO | run-starfit | Performance of reservoir 364 has been computed
# 2025-04-10 16:51:12 | INFO | run-starfit | Scatter plot of simulation from reservoir 364
# 2025-04-10 16:51:12 | INFO | run-starfit | Line plot of simulation from reservoir 364
# 2025-04-10 16:51:12 | INFO | run-starfit | Simulating reservoir 367
# 2025-04-10 16:51:13 | INFO | run-starfit | Simulation of the calibrated reservoir 367 successfully finished
# 2025-04-10 16:51:13 | INFO | run-starfit | Performance of reservoir 367 has been computed
# 2025-04-10 16:51:14 | INFO | run-starfit | Scatter plot of simulation from reservoir 367
# 2025-04-10 16:51:14 | INFO | run-starfit | Line plot of simulation from reservoir 367
# 2025-04-10 16:51:14 | INFO | run-starfit | Simulating reservoir 368
# 2025-04-10 16:51:15 | INFO | run-starfit | Simulation of the calibrated reservoir 368 successfully finished
# 2025-04-10 16:51:15 | INFO | run-starfit | Performance of reservoir 368 has been computed
# 2025-04-10 16:51:16 | INFO | run-starfit | Scatter plot of simulation from reservoir 368
# 2025-04-10 16:51:16 | INFO | run-starfit | Line plot of simulation from reservoir 368
# 2025-04-10 16:51:16 | INFO | run-starfit | Simulating reservoir 372
# 2025-04-10 16:51:17 | INFO | run-starfit | Simulation of the calibrated reservoir 372 successfully finished
# 2025-04-10 16:51:17 | INFO | run-starfit | Performance of reservoir 372 has been computed
# 2025-04-10 16:51:18 | INFO | run-starfit | Scatter plot of simulation from reservoir 372
# 2025-04-10 16:51:18 | INFO | run-starfit | Line plot of simulation from reservoir 372
# 2025-04-10 16:51:18 | INFO | run-starfit | Simulating reservoir 373
# 2025-04-10 16:51:22 | INFO | run-starfit | Simulation of the calibrated reservoir 373 successfully finished
# 2025-04-10 16:51:22 | INFO | run-starfit | Performance of reservoir 373 has been computed
# 2025-04-10 16:51:23 | INFO | run-starfit | Scatter plot of simulation from reservoir 373
# 2025-04-10 16:51:23 | INFO | run-starfit | Line plot of simulation from reservoir 373
# 2025-04-10 16:51:23 | INFO | run-starfit | Simulating reservoir 384
# 2025-04-10 16:51:27 | INFO | run-starfit | Simulation of the calibrated reservoir 384 successfully finished
# 2025-04-10 16:51:27 | INFO | run-starfit | Performance of reservoir 384 has been computed
# 2025-04-10 16:51:28 | INFO | run-starfit | Scatter plot of simulation from reservoir 384
# 2025-04-10 16:51:29 | INFO | run-starfit | Line plot of simulation from reservoir 384
# 2025-04-10 16:51:29 | INFO | run-starfit | Simulating reservoir 390
# 2025-04-10 16:51:29 | INFO | run-starfit | Simulation of the calibrated reservoir 390 successfully finished
# 2025-04-10 16:51:29 | INFO | run-starfit | Performance of reservoir 390 has been computed
# 2025-04-10 16:51:30 | INFO | run-starfit | Scatter plot of simulation from reservoir 390
# 2025-04-10 16:51:30 | INFO | run-starfit | Line plot of simulation from reservoir 390
# 2025-04-10 16:51:30 | INFO | run-starfit | Simulating reservoir 391
# 2025-04-10 16:51:32 | INFO | run-starfit | Simulation of the calibrated reservoir 391 successfully finished
# 2025-04-10 16:51:32 | INFO | run-starfit | Performance of reservoir 391 has been computed
# 2025-04-10 16:51:33 | INFO | run-starfit | Scatter plot of simulation from reservoir 391
# 2025-04-10 16:51:33 | INFO | run-starfit | Line plot of simulation from reservoir 391
# 2025-04-10 16:51:33 | INFO | run-starfit | Simulating reservoir 393
# 2025-04-10 16:51:37 | INFO | run-starfit | Simulation of the calibrated reservoir 393 successfully finished
# 2025-04-10 16:51:37 | INFO | run-starfit | Performance of reservoir 393 has been computed
# 2025-04-10 16:51:38 | INFO | run-starfit | Scatter plot of simulation from reservoir 393
# 2025-04-10 16:51:38 | INFO | run-starfit | Line plot of simulation from reservoir 393
# 2025-04-10 16:51:38 | INFO | run-starfit | Simulating reservoir 398
# 2025-04-10 16:51:42 | INFO | run-starfit | Simulation of the calibrated reservoir 398 successfully finished
# 2025-04-10 16:51:42 | INFO | run-starfit | Performance of reservoir 398 has been computed
# 2025-04-10 16:51:43 | INFO | run-starfit | Scatter plot of simulation from reservoir 398
# 2025-04-10 16:51:44 | INFO | run-starfit | Line plot of simulation from reservoir 398
# 2025-04-10 16:51:44 | INFO | run-starfit | Simulating reservoir 416
# 2025-04-10 16:51:46 | INFO | run-starfit | Simulation of the calibrated reservoir 416 successfully finished
# 2025-04-10 16:51:46 | INFO | run-starfit | Performance of reservoir 416 has been computed
# 2025-04-10 16:51:47 | INFO | run-starfit | Scatter plot of simulation from reservoir 416
# 2025-04-10 16:51:48 | INFO | run-starfit | Line plot of simulation from reservoir 416
# 2025-04-10 16:51:48 | INFO | run-starfit | Simulating reservoir 419
# 2025-04-10 16:51:49 | INFO | run-starfit | Simulation of the calibrated reservoir 419 successfully finished
# 2025-04-10 16:51:49 | INFO | run-starfit | Performance of reservoir 419 has been computed
# 2025-04-10 16:51:49 | INFO | run-starfit | Scatter plot of simulation from reservoir 419
# 2025-04-10 16:51:50 | INFO | run-starfit | Line plot of simulation from reservoir 419
# 2025-04-10 16:51:50 | INFO | run-starfit | Simulating reservoir 421
# 2025-04-10 16:51:54 | INFO | run-starfit | Simulation of the calibrated reservoir 421 successfully finished
# 2025-04-10 16:51:54 | INFO | run-starfit | Performance of reservoir 421 has been computed
# 2025-04-10 16:51:55 | INFO | run-starfit | Scatter plot of simulation from reservoir 421
# 2025-04-10 16:51:55 | INFO | run-starfit | Line plot of simulation from reservoir 421
# 2025-04-10 16:51:55 | INFO | run-starfit | Simulating reservoir 423
# 2025-04-10 16:51:58 | INFO | run-starfit | Simulation of the calibrated reservoir 423 successfully finished
# 2025-04-10 16:51:58 | INFO | run-starfit | Performance of reservoir 423 has been computed
# 2025-04-10 16:51:59 | INFO | run-starfit | Scatter plot of simulation from reservoir 423
# 2025-04-10 16:52:00 | INFO | run-starfit | Line plot of simulation from reservoir 423
# 2025-04-10 16:52:00 | INFO | run-starfit | Simulating reservoir 431
# 2025-04-10 16:52:00 | INFO | run-starfit | Simulation of the calibrated reservoir 431 successfully finished
# 2025-04-10 16:52:00 | INFO | run-starfit | Performance of reservoir 431 has been computed
# 2025-04-10 16:52:01 | INFO | run-starfit | Scatter plot of simulation from reservoir 431
# 2025-04-10 16:52:01 | INFO | run-starfit | Line plot of simulation from reservoir 431
# 2025-04-10 16:52:01 | INFO | run-starfit | Simulating reservoir 438
# 2025-04-10 16:52:02 | INFO | run-starfit | Simulation of the calibrated reservoir 438 successfully finished
# 2025-04-10 16:52:02 | INFO | run-starfit | Performance of reservoir 438 has been computed
# 2025-04-10 16:52:03 | INFO | run-starfit | Scatter plot of simulation from reservoir 438
# 2025-04-10 16:52:03 | INFO | run-starfit | Line plot of simulation from reservoir 438
# 2025-04-10 16:52:03 | INFO | run-starfit | Simulating reservoir 442
# 2025-04-10 16:52:05 | INFO | run-starfit | Simulation of the calibrated reservoir 442 successfully finished
# 2025-04-10 16:52:05 | INFO | run-starfit | Performance of reservoir 442 has been computed
# 2025-04-10 16:52:06 | INFO | run-starfit | Scatter plot of simulation from reservoir 442
# 2025-04-10 16:52:07 | INFO | run-starfit | Line plot of simulation from reservoir 442
# 2025-04-10 16:52:07 | INFO | run-starfit | Simulating reservoir 445
# 2025-04-10 16:52:09 | INFO | run-starfit | Simulation of the calibrated reservoir 445 successfully finished
# 2025-04-10 16:52:09 | INFO | run-starfit | Performance of reservoir 445 has been computed
# 2025-04-10 16:52:09 | INFO | run-starfit | Scatter plot of simulation from reservoir 445
# 2025-04-10 16:52:10 | INFO | run-starfit | Line plot of simulation from reservoir 445
# 2025-04-10 16:52:10 | INFO | run-starfit | Simulating reservoir 449
# 2025-04-10 16:52:12 | INFO | run-starfit | Simulation of the calibrated reservoir 449 successfully finished
# 2025-04-10 16:52:12 | INFO | run-starfit | Performance of reservoir 449 has been computed
# 2025-04-10 16:52:12 | INFO | run-starfit | Scatter plot of simulation from reservoir 449
# 2025-04-10 16:52:13 | INFO | run-starfit | Line plot of simulation from reservoir 449
# 2025-04-10 16:52:13 | INFO | run-starfit | Simulating reservoir 450
# 2025-04-10 16:52:13 | INFO | run-starfit | Simulation of the calibrated reservoir 450 successfully finished
# 2025-04-10 16:52:13 | INFO | run-starfit | Performance of reservoir 450 has been computed
# 2025-04-10 16:52:14 | INFO | run-starfit | Scatter plot of simulation from reservoir 450
# 2025-04-10 16:52:14 | INFO | run-starfit | Line plot of simulation from reservoir 450
# 2025-04-10 16:52:14 | INFO | run-starfit | Simulating reservoir 451
# 2025-04-10 16:52:18 | INFO | run-starfit | Simulation of the calibrated reservoir 451 successfully finished
# 2025-04-10 16:52:18 | INFO | run-starfit | Performance of reservoir 451 has been computed
# 2025-04-10 16:52:19 | INFO | run-starfit | Scatter plot of simulation from reservoir 451
# 2025-04-10 16:52:20 | INFO | run-starfit | Line plot of simulation from reservoir 451
# 2025-04-10 16:52:20 | INFO | run-starfit | Simulating reservoir 456
# 2025-04-10 16:52:22 | INFO | run-starfit | Simulation of the calibrated reservoir 456 successfully finished
# 2025-04-10 16:52:22 | INFO | run-starfit | Performance of reservoir 456 has been computed
# 2025-04-10 16:52:23 | INFO | run-starfit | Scatter plot of simulation from reservoir 456
# 2025-04-10 16:52:23 | INFO | run-starfit | Line plot of simulation from reservoir 456
# 2025-04-10 16:52:23 | INFO | run-starfit | Simulating reservoir 467
# 2025-04-10 16:52:25 | INFO | run-starfit | Simulation of the calibrated reservoir 467 successfully finished
# 2025-04-10 16:52:25 | INFO | run-starfit | Performance of reservoir 467 has been computed
# 2025-04-10 16:52:26 | INFO | run-starfit | Scatter plot of simulation from reservoir 467
# 2025-04-10 16:52:26 | INFO | run-starfit | Line plot of simulation from reservoir 467
# 2025-04-10 16:52:26 | INFO | run-starfit | Simulating reservoir 471
# 2025-04-10 16:52:27 | INFO | run-starfit | Simulation of the calibrated reservoir 471 successfully finished
# 2025-04-10 16:52:27 | INFO | run-starfit | Performance of reservoir 471 has been computed
# 2025-04-10 16:52:28 | INFO | run-starfit | Scatter plot of simulation from reservoir 471
# 2025-04-10 16:52:28 | INFO | run-starfit | Line plot of simulation from reservoir 471
# 2025-04-10 16:52:28 | INFO | run-starfit | Simulating reservoir 477
# 2025-04-10 16:52:30 | INFO | run-starfit | Simulation of the calibrated reservoir 477 successfully finished
# 2025-04-10 16:52:30 | INFO | run-starfit | Performance of reservoir 477 has been computed
# 2025-04-10 16:52:31 | INFO | run-starfit | Scatter plot of simulation from reservoir 477
# 2025-04-10 16:52:31 | INFO | run-starfit | Line plot of simulation from reservoir 477
# 2025-04-10 16:52:31 | INFO | run-starfit | Simulating reservoir 488
# 2025-04-10 16:52:32 | INFO | run-starfit | Simulation of the calibrated reservoir 488 successfully finished
# 2025-04-10 16:52:32 | INFO | run-starfit | Performance of reservoir 488 has been computed
# 2025-04-10 16:52:33 | INFO | run-starfit | Scatter plot of simulation from reservoir 488
# 2025-04-10 16:52:33 | INFO | run-starfit | Line plot of simulation from reservoir 488
# 2025-04-10 16:52:33 | INFO | run-starfit | Simulating reservoir 497
# 2025-04-10 16:52:37 | INFO | run-starfit | Simulation of the calibrated reservoir 497 successfully finished
# 2025-04-10 16:52:37 | INFO | run-starfit | Performance of reservoir 497 has been computed
# 2025-04-10 16:52:38 | INFO | run-starfit | Scatter plot of simulation from reservoir 497
# 2025-04-10 16:52:39 | INFO | run-starfit | Line plot of simulation from reservoir 497
# 2025-04-10 16:52:39 | INFO | run-starfit | Simulating reservoir 502
# 2025-04-10 16:52:42 | INFO | run-starfit | Simulation of the calibrated reservoir 502 successfully finished
# 2025-04-10 16:52:42 | INFO | run-starfit | Performance of reservoir 502 has been computed
# 2025-04-10 16:52:42 | INFO | run-starfit | Scatter plot of simulation from reservoir 502
# 2025-04-10 16:52:43 | INFO | run-starfit | Line plot of simulation from reservoir 502
# 2025-04-10 16:52:43 | INFO | run-starfit | Simulating reservoir 506
# 2025-04-10 16:52:43 | INFO | run-starfit | Simulation of the calibrated reservoir 506 successfully finished
# 2025-04-10 16:52:43 | INFO | run-starfit | Performance of reservoir 506 has been computed
# 2025-04-10 16:52:44 | INFO | run-starfit | Scatter plot of simulation from reservoir 506
# 2025-04-10 16:52:44 | INFO | run-starfit | Line plot of simulation from reservoir 506
# 2025-04-10 16:52:44 | INFO | run-starfit | Simulating reservoir 507
# 2025-04-10 16:52:45 | INFO | run-starfit | Simulation of the calibrated reservoir 507 successfully finished
# 2025-04-10 16:52:45 | INFO | run-starfit | Performance of reservoir 507 has been computed
# 2025-04-10 16:52:45 | INFO | run-starfit | Scatter plot of simulation from reservoir 507
# 2025-04-10 16:52:46 | INFO | run-starfit | Line plot of simulation from reservoir 507
# 2025-04-10 16:52:46 | INFO | run-starfit | Simulating reservoir 511
# 2025-04-10 16:52:47 | INFO | run-starfit | Simulation of the calibrated reservoir 511 successfully finished
# 2025-04-10 16:52:47 | INFO | run-starfit | Performance of reservoir 511 has been computed
# 2025-04-10 16:52:48 | INFO | run-starfit | Scatter plot of simulation from reservoir 511
# 2025-04-10 16:52:48 | INFO | run-starfit | Line plot of simulation from reservoir 511
# 2025-04-10 16:52:48 | INFO | run-starfit | Simulating reservoir 517
# 2025-04-10 16:52:51 | INFO | run-starfit | Simulation of the calibrated reservoir 517 successfully finished
# 2025-04-10 16:52:51 | INFO | run-starfit | Performance of reservoir 517 has been computed
# 2025-04-10 16:52:52 | INFO | run-starfit | Scatter plot of simulation from reservoir 517
# 2025-04-10 16:52:52 | INFO | run-starfit | Line plot of simulation from reservoir 517
# 2025-04-10 16:52:52 | INFO | run-starfit | Simulating reservoir 518
# 2025-04-10 16:52:54 | INFO | run-starfit | Simulation of the calibrated reservoir 518 successfully finished
# 2025-04-10 16:52:54 | INFO | run-starfit | Performance of reservoir 518 has been computed
# 2025-04-10 16:52:54 | INFO | run-starfit | Scatter plot of simulation from reservoir 518
# 2025-04-10 16:52:55 | INFO | run-starfit | Line plot of simulation from reservoir 518
# 2025-04-10 16:52:55 | INFO | run-starfit | Simulating reservoir 522
# 2025-04-10 16:52:57 | INFO | run-starfit | Simulation of the calibrated reservoir 522 successfully finished
# 2025-04-10 16:52:57 | INFO | run-starfit | Performance of reservoir 522 has been computed
# 2025-04-10 16:52:58 | INFO | run-starfit | Scatter plot of simulation from reservoir 522
# 2025-04-10 16:52:58 | INFO | run-starfit | Line plot of simulation from reservoir 522
# 2025-04-10 16:52:58 | INFO | run-starfit | Simulating reservoir 529
# 2025-04-10 16:52:59 | INFO | run-starfit | Simulation of the calibrated reservoir 529 successfully finished
# 2025-04-10 16:52:59 | INFO | run-starfit | Performance of reservoir 529 has been computed
# 2025-04-10 16:52:59 | INFO | run-starfit | Scatter plot of simulation from reservoir 529
# 2025-04-10 16:53:00 | INFO | run-starfit | Line plot of simulation from reservoir 529
# 2025-04-10 16:53:00 | INFO | run-starfit | Simulating reservoir 530
# 2025-04-10 16:53:03 | INFO | run-starfit | Simulation of the calibrated reservoir 530 successfully finished
# 2025-04-10 16:53:03 | INFO | run-starfit | Performance of reservoir 530 has been computed
# 2025-04-10 16:53:04 | INFO | run-starfit | Scatter plot of simulation from reservoir 530
# 2025-04-10 16:53:04 | INFO | run-starfit | Line plot of simulation from reservoir 530
# 2025-04-10 16:53:04 | INFO | run-starfit | Simulating reservoir 531
# 2025-04-10 16:53:04 | INFO | run-starfit | Simulation of the calibrated reservoir 531 successfully finished
# 2025-04-10 16:53:04 | INFO | run-starfit | Performance of reservoir 531 has been computed
# 2025-04-10 16:53:05 | INFO | run-starfit | Scatter plot of simulation from reservoir 531
# 2025-04-10 16:53:06 | INFO | run-starfit | Line plot of simulation from reservoir 531
# 2025-04-10 16:53:06 | INFO | run-starfit | Simulating reservoir 533
# 2025-04-10 16:53:08 | INFO | run-starfit | Simulation of the calibrated reservoir 533 successfully finished
# 2025-04-10 16:53:08 | INFO | run-starfit | Performance of reservoir 533 has been computed
# 2025-04-10 16:53:09 | INFO | run-starfit | Scatter plot of simulation from reservoir 533
# 2025-04-10 16:53:09 | INFO | run-starfit | Line plot of simulation from reservoir 533
# 2025-04-10 16:53:09 | INFO | run-starfit | Simulating reservoir 536
# 2025-04-10 16:53:11 | INFO | run-starfit | Simulation of the calibrated reservoir 536 successfully finished
# 2025-04-10 16:53:11 | INFO | run-starfit | Performance of reservoir 536 has been computed
# 2025-04-10 16:53:12 | INFO | run-starfit | Scatter plot of simulation from reservoir 536
# 2025-04-10 16:53:12 | INFO | run-starfit | Line plot of simulation from reservoir 536
# 2025-04-10 16:53:12 | INFO | run-starfit | Simulating reservoir 541
# 2025-04-10 16:53:16 | INFO | run-starfit | Simulation of the calibrated reservoir 541 successfully finished
# 2025-04-10 16:53:16 | INFO | run-starfit | Performance of reservoir 541 has been computed
# 2025-04-10 16:53:17 | INFO | run-starfit | Scatter plot of simulation from reservoir 541
# 2025-04-10 16:53:18 | INFO | run-starfit | Line plot of simulation from reservoir 541
# 2025-04-10 16:53:18 | INFO | run-starfit | Simulating reservoir 575
# 2025-04-10 16:53:22 | INFO | run-starfit | Simulation of the calibrated reservoir 575 successfully finished
# 2025-04-10 16:53:22 | INFO | run-starfit | Performance of reservoir 575 has been computed
# 2025-04-10 16:53:23 | INFO | run-starfit | Scatter plot of simulation from reservoir 575
# 2025-04-10 16:53:23 | INFO | run-starfit | Line plot of simulation from reservoir 575
# 2025-04-10 16:53:23 | INFO | run-starfit | Simulating reservoir 595
# 2025-04-10 16:53:25 | INFO | run-starfit | Simulation of the calibrated reservoir 595 successfully finished
# 2025-04-10 16:53:25 | INFO | run-starfit | Performance of reservoir 595 has been computed
# 2025-04-10 16:53:26 | INFO | run-starfit | Scatter plot of simulation from reservoir 595
# 2025-04-10 16:53:26 | INFO | run-starfit | Line plot of simulation from reservoir 595
# 2025-04-10 16:53:26 | INFO | run-starfit | Simulating reservoir 597
# 2025-04-10 16:53:30 | INFO | run-starfit | Simulation of the calibrated reservoir 597 successfully finished
# 2025-04-10 16:53:30 | INFO | run-starfit | Performance of reservoir 597 has been computed
# 2025-04-10 16:53:31 | INFO | run-starfit | Scatter plot of simulation from reservoir 597
# 2025-04-10 16:53:32 | INFO | run-starfit | Line plot of simulation from reservoir 597
# 2025-04-10 16:53:32 | INFO | run-starfit | Simulating reservoir 601
# 2025-04-10 16:53:36 | INFO | run-starfit | Simulation of the calibrated reservoir 601 successfully finished
# 2025-04-10 16:53:36 | INFO | run-starfit | Performance of reservoir 601 has been computed
# 2025-04-10 16:53:37 | INFO | run-starfit | Scatter plot of simulation from reservoir 601
# 2025-04-10 16:53:37 | INFO | run-starfit | Line plot of simulation from reservoir 601
# 2025-04-10 16:53:37 | INFO | run-starfit | Simulating reservoir 657
# 2025-04-10 16:53:38 | INFO | run-starfit | Simulation of the calibrated reservoir 657 successfully finished
# 2025-04-10 16:53:38 | INFO | run-starfit | Performance of reservoir 657 has been computed
# 2025-04-10 16:53:39 | INFO | run-starfit | Scatter plot of simulation from reservoir 657
# 2025-04-10 16:53:39 | INFO | run-starfit | Line plot of simulation from reservoir 657
# 2025-04-10 16:53:39 | INFO | run-starfit | Simulating reservoir 753
# 2025-04-10 16:53:42 | INFO | run-starfit | Simulation of the calibrated reservoir 753 successfully finished
# 2025-04-10 16:53:42 | INFO | run-starfit | Performance of reservoir 753 has been computed
# 2025-04-10 16:53:43 | INFO | run-starfit | Scatter plot of simulation from reservoir 753
# 2025-04-10 16:53:43 | INFO | run-starfit | Line plot of simulation from reservoir 753
# 2025-04-10 16:53:43 | INFO | run-starfit | Simulating reservoir 780
# 2025-04-10 16:53:44 | INFO | run-starfit | Simulation of the calibrated reservoir 780 successfully finished
# 2025-04-10 16:53:44 | INFO | run-starfit | Performance of reservoir 780 has been computed
# 2025-04-10 16:53:45 | INFO | run-starfit | Scatter plot of simulation from reservoir 780
# 2025-04-10 16:53:45 | INFO | run-starfit | Line plot of simulation from reservoir 780
# 2025-04-10 16:53:45 | INFO | run-starfit | Simulating reservoir 789
# 2025-04-10 16:53:47 | INFO | run-starfit | Simulation of the calibrated reservoir 789 successfully finished
# 2025-04-10 16:53:47 | INFO | run-starfit | Performance of reservoir 789 has been computed
# 2025-04-10 16:53:48 | INFO | run-starfit | Scatter plot of simulation from reservoir 789
# 2025-04-10 16:53:49 | INFO | run-starfit | Line plot of simulation from reservoir 789
# 2025-04-10 16:53:49 | INFO | run-starfit | Simulating reservoir 868
# 2025-04-10 16:53:49 | INFO | run-starfit | Simulation of the calibrated reservoir 868 successfully finished
# 2025-04-10 16:53:49 | INFO | run-starfit | Performance of reservoir 868 has been computed
# 2025-04-10 16:53:50 | INFO | run-starfit | Scatter plot of simulation from reservoir 868
# 2025-04-10 16:53:50 | INFO | run-starfit | Line plot of simulation from reservoir 868
# 2025-04-10 16:53:50 | INFO | run-starfit | Simulating reservoir 870
# 2025-04-10 16:53:51 | INFO | run-starfit | Simulation of the calibrated reservoir 870 successfully finished
# 2025-04-10 16:53:51 | INFO | run-starfit | Performance of reservoir 870 has been computed
# 2025-04-10 16:53:52 | INFO | run-starfit | Scatter plot of simulation from reservoir 870
# 2025-04-10 16:53:53 | INFO | run-starfit | Line plot of simulation from reservoir 870
# 2025-04-10 16:53:53 | INFO | run-starfit | Simulating reservoir 882
# 2025-04-10 16:53:56 | INFO | run-starfit | Simulation of the calibrated reservoir 882 successfully finished
# 2025-04-10 16:53:56 | INFO | run-starfit | Performance of reservoir 882 has been computed
# 2025-04-10 16:53:57 | INFO | run-starfit | Scatter plot of simulation from reservoir 882
# 2025-04-10 16:53:58 | INFO | run-starfit | Line plot of simulation from reservoir 882
# 2025-04-10 16:53:58 | INFO | run-starfit | Simulating reservoir 893
# 2025-04-10 16:53:58 | INFO | run-starfit | Simulation of the calibrated reservoir 893 successfully finished
# 2025-04-10 16:53:58 | INFO | run-starfit | Performance of reservoir 893 has been computed
# 2025-04-10 16:53:59 | INFO | run-starfit | Scatter plot of simulation from reservoir 893
# 2025-04-10 16:53:59 | INFO | run-starfit | Line plot of simulation from reservoir 893
# 2025-04-10 16:53:59 | INFO | run-starfit | Simulating reservoir 898
# 2025-04-10 16:54:03 | INFO | run-starfit | Simulation of the calibrated reservoir 898 successfully finished
# 2025-04-10 16:54:03 | INFO | run-starfit | Performance of reservoir 898 has been computed
# 2025-04-10 16:54:04 | INFO | run-starfit | Scatter plot of simulation from reservoir 898
# 2025-04-10 16:54:04 | INFO | run-starfit | Line plot of simulation from reservoir 898
# 2025-04-10 16:54:04 | INFO | run-starfit | Simulating reservoir 938
# 2025-04-10 16:54:05 | INFO | run-starfit | Simulation of the calibrated reservoir 938 successfully finished
# 2025-04-10 16:54:05 | INFO | run-starfit | Performance of reservoir 938 has been computed
# 2025-04-10 16:54:06 | INFO | run-starfit | Scatter plot of simulation from reservoir 938
# 2025-04-10 16:54:06 | INFO | run-starfit | Line plot of simulation from reservoir 938
# 2025-04-10 16:54:06 | INFO | run-starfit | Simulating reservoir 952
# 2025-04-10 16:54:07 | INFO | run-starfit | Simulation of the calibrated reservoir 952 successfully finished
# 2025-04-10 16:54:07 | INFO | run-starfit | Performance of reservoir 952 has been computed
# 2025-04-10 16:54:08 | INFO | run-starfit | Scatter plot of simulation from reservoir 952
# 2025-04-10 16:54:08 | INFO | run-starfit | Line plot of simulation from reservoir 952
# 2025-04-10 16:54:08 | INFO | run-starfit | Simulating reservoir 957
# 2025-04-10 16:54:10 | INFO | run-starfit | Simulation of the calibrated reservoir 957 successfully finished
# 2025-04-10 16:54:10 | INFO | run-starfit | Performance of reservoir 957 has been computed
# 2025-04-10 16:54:11 | INFO | run-starfit | Scatter plot of simulation from reservoir 957
# 2025-04-10 16:54:11 | INFO | run-starfit | Line plot of simulation from reservoir 957
# 2025-04-10 16:54:11 | INFO | run-starfit | Simulating reservoir 982
# 2025-04-10 16:54:15 | INFO | run-starfit | Simulation of the calibrated reservoir 982 successfully finished
# 2025-04-10 16:54:15 | INFO | run-starfit | Performance of reservoir 982 has been computed
# 2025-04-10 16:54:16 | INFO | run-starfit | Scatter plot of simulation from reservoir 982
# 2025-04-10 16:54:16 | INFO | run-starfit | Line plot of simulation from reservoir 982
# 2025-04-10 16:54:16 | INFO | run-starfit | Simulating reservoir 987
# 2025-04-10 16:54:19 | INFO | run-starfit | Simulation of the calibrated reservoir 987 successfully finished
# 2025-04-10 16:54:19 | INFO | run-starfit | Performance of reservoir 987 has been computed
# 2025-04-10 16:54:20 | INFO | run-starfit | Scatter plot of simulation from reservoir 987
# 2025-04-10 16:54:20 | INFO | run-starfit | Line plot of simulation from reservoir 987
# 2025-04-10 16:54:20 | INFO | run-starfit | Simulating reservoir 989
# 2025-04-10 16:54:23 | INFO | run-starfit | Simulation of the calibrated reservoir 989 successfully finished
# 2025-04-10 16:54:24 | INFO | run-starfit | Performance of reservoir 989 has been computed
# 2025-04-10 16:54:24 | INFO | run-starfit | Scatter plot of simulation from reservoir 989
# 2025-04-10 16:54:25 | INFO | run-starfit | Line plot of simulation from reservoir 989
# 2025-04-10 16:54:25 | INFO | run-starfit | Simulating reservoir 1006
# 2025-04-10 16:54:28 | INFO | run-starfit | Simulation of the calibrated reservoir 1006 successfully finished
# 2025-04-10 16:54:28 | INFO | run-starfit | Performance of reservoir 1006 has been computed
# 2025-04-10 16:54:29 | INFO | run-starfit | Scatter plot of simulation from reservoir 1006
# 2025-04-10 16:54:30 | INFO | run-starfit | Line plot of simulation from reservoir 1006
# 2025-04-10 16:54:30 | INFO | run-starfit | Simulating reservoir 1020
# 2025-04-10 16:54:30 | INFO | run-starfit | Simulation of the calibrated reservoir 1020 successfully finished
# 2025-04-10 16:54:30 | INFO | run-starfit | Performance of reservoir 1020 has been computed
# 2025-04-10 16:54:31 | INFO | run-starfit | Scatter plot of simulation from reservoir 1020
# 2025-04-10 16:54:31 | INFO | run-starfit | Line plot of simulation from reservoir 1020
# 2025-04-10 16:54:31 | INFO | run-starfit | Simulating reservoir 1023
# 2025-04-10 16:54:32 | INFO | run-starfit | Simulation of the calibrated reservoir 1023 successfully finished
# 2025-04-10 16:54:32 | INFO | run-starfit | Performance of reservoir 1023 has been computed
# 2025-04-10 16:54:33 | INFO | run-starfit | Scatter plot of simulation from reservoir 1023
# 2025-04-10 16:54:33 | INFO | run-starfit | Line plot of simulation from reservoir 1023
# 2025-04-10 16:54:33 | INFO | run-starfit | Simulating reservoir 1026
# 2025-04-10 16:54:37 | INFO | run-starfit | Simulation of the calibrated reservoir 1026 successfully finished
# 2025-04-10 16:54:37 | INFO | run-starfit | Performance of reservoir 1026 has been computed
# 2025-04-10 16:54:38 | INFO | run-starfit | Scatter plot of simulation from reservoir 1026
# 2025-04-10 16:54:38 | INFO | run-starfit | Line plot of simulation from reservoir 1026
# 2025-04-10 16:54:38 | INFO | run-starfit | Simulating reservoir 1027
# 2025-04-10 16:54:40 | INFO | run-starfit | Simulation of the calibrated reservoir 1027 successfully finished
# 2025-04-10 16:54:40 | INFO | run-starfit | Performance of reservoir 1027 has been computed
# 2025-04-10 16:54:41 | INFO | run-starfit | Scatter plot of simulation from reservoir 1027
# 2025-04-10 16:54:42 | INFO | run-starfit | Line plot of simulation from reservoir 1027
# 2025-04-10 16:54:42 | INFO | run-starfit | Simulating reservoir 1032
# 2025-04-10 16:54:45 | INFO | run-starfit | Simulation of the calibrated reservoir 1032 successfully finished
# 2025-04-10 16:54:45 | INFO | run-starfit | Performance of reservoir 1032 has been computed
# 2025-04-10 16:54:45 | INFO | run-starfit | Scatter plot of simulation from reservoir 1032
# 2025-04-10 16:54:46 | INFO | run-starfit | Line plot of simulation from reservoir 1032
# 2025-04-10 16:54:46 | INFO | run-starfit | Simulating reservoir 1033
# 2025-04-10 16:54:50 | INFO | run-starfit | Simulation of the calibrated reservoir 1033 successfully finished
# 2025-04-10 16:54:50 | INFO | run-starfit | Performance of reservoir 1033 has been computed
# 2025-04-10 16:54:50 | INFO | run-starfit | Scatter plot of simulation from reservoir 1033
# 2025-04-10 16:54:51 | INFO | run-starfit | Line plot of simulation from reservoir 1033
# 2025-04-10 16:54:51 | INFO | run-starfit | Simulating reservoir 1036
# 2025-04-10 16:54:55 | INFO | run-starfit | Simulation of the calibrated reservoir 1036 successfully finished
# 2025-04-10 16:54:55 | INFO | run-starfit | Performance of reservoir 1036 has been computed
# 2025-04-10 16:54:56 | INFO | run-starfit | Scatter plot of simulation from reservoir 1036
# 2025-04-10 16:54:56 | INFO | run-starfit | Line plot of simulation from reservoir 1036
# 2025-04-10 16:54:56 | INFO | run-starfit | Simulating reservoir 1042
# 2025-04-10 16:55:00 | INFO | run-starfit | Simulation of the calibrated reservoir 1042 successfully finished
# 2025-04-10 16:55:00 | INFO | run-starfit | Performance of reservoir 1042 has been computed
# 2025-04-10 16:55:01 | INFO | run-starfit | Scatter plot of simulation from reservoir 1042
# 2025-04-10 16:55:01 | INFO | run-starfit | Line plot of simulation from reservoir 1042
# 2025-04-10 16:55:01 | INFO | run-starfit | Simulating reservoir 1048
# 2025-04-10 16:55:03 | INFO | run-starfit | Simulation of the calibrated reservoir 1048 successfully finished
# 2025-04-10 16:55:03 | INFO | run-starfit | Performance of reservoir 1048 has been computed
# 2025-04-10 16:55:03 | INFO | run-starfit | Scatter plot of simulation from reservoir 1048
# 2025-04-10 16:55:03 | INFO | run-starfit | Line plot of simulation from reservoir 1048
# 2025-04-10 16:55:03 | INFO | run-starfit | Simulating reservoir 1053
# 2025-04-10 16:55:05 | INFO | run-starfit | Simulation of the calibrated reservoir 1053 successfully finished
# 2025-04-10 16:55:05 | INFO | run-starfit | Performance of reservoir 1053 has been computed
# 2025-04-10 16:55:06 | INFO | run-starfit | Scatter plot of simulation from reservoir 1053
# 2025-04-10 16:55:06 | INFO | run-starfit | Line plot of simulation from reservoir 1053
# 2025-04-10 16:55:06 | INFO | run-starfit | Simulating reservoir 1067
# 2025-04-10 16:55:10 | INFO | run-starfit | Simulation of the calibrated reservoir 1067 successfully finished
# 2025-04-10 16:55:10 | INFO | run-starfit | Performance of reservoir 1067 has been computed
# 2025-04-10 16:55:11 | INFO | run-starfit | Scatter plot of simulation from reservoir 1067
# 2025-04-10 16:55:11 | INFO | run-starfit | Line plot of simulation from reservoir 1067
# 2025-04-10 16:55:11 | INFO | run-starfit | Simulating reservoir 1070
# 2025-04-10 16:55:13 | INFO | run-starfit | Simulation of the calibrated reservoir 1070 successfully finished
# 2025-04-10 16:55:13 | INFO | run-starfit | Performance of reservoir 1070 has been computed
# 2025-04-10 16:55:14 | INFO | run-starfit | Scatter plot of simulation from reservoir 1070
# 2025-04-10 16:55:14 | INFO | run-starfit | Line plot of simulation from reservoir 1070
# 2025-04-10 16:55:14 | INFO | run-starfit | Simulating reservoir 1086
# 2025-04-10 16:55:17 | INFO | run-starfit | Simulation of the calibrated reservoir 1086 successfully finished
# 2025-04-10 16:55:17 | INFO | run-starfit | Performance of reservoir 1086 has been computed
# 2025-04-10 16:55:18 | INFO | run-starfit | Scatter plot of simulation from reservoir 1086
# 2025-04-10 16:55:18 | INFO | run-starfit | Line plot of simulation from reservoir 1086
# 2025-04-10 16:55:18 | INFO | run-starfit | Simulating reservoir 1112
# 2025-04-10 16:55:20 | INFO | run-starfit | Simulation of the calibrated reservoir 1112 successfully finished
# 2025-04-10 16:55:20 | INFO | run-starfit | Performance of reservoir 1112 has been computed
# 2025-04-10 16:55:21 | INFO | run-starfit | Scatter plot of simulation from reservoir 1112
# 2025-04-10 16:55:21 | INFO | run-starfit | Line plot of simulation from reservoir 1112
# 2025-04-10 16:55:21 | INFO | run-starfit | Simulating reservoir 1121
# 2025-04-10 16:55:24 | INFO | run-starfit | Simulation of the calibrated reservoir 1121 successfully finished
# 2025-04-10 16:55:24 | INFO | run-starfit | Performance of reservoir 1121 has been computed
# 2025-04-10 16:55:25 | INFO | run-starfit | Scatter plot of simulation from reservoir 1121
# 2025-04-10 16:55:26 | INFO | run-starfit | Line plot of simulation from reservoir 1121
# 2025-04-10 16:55:26 | INFO | run-starfit | Simulating reservoir 1124
# 2025-04-10 16:55:27 | INFO | run-starfit | Simulation of the calibrated reservoir 1124 successfully finished
# 2025-04-10 16:55:27 | INFO | run-starfit | Performance of reservoir 1124 has been computed
# 2025-04-10 16:55:28 | INFO | run-starfit | Scatter plot of simulation from reservoir 1124
# 2025-04-10 16:55:28 | INFO | run-starfit | Line plot of simulation from reservoir 1124
# 2025-04-10 16:55:28 | INFO | run-starfit | Simulating reservoir 1125
# 2025-04-10 16:55:31 | INFO | run-starfit | Simulation of the calibrated reservoir 1125 successfully finished
# 2025-04-10 16:55:31 | INFO | run-starfit | Performance of reservoir 1125 has been computed
# 2025-04-10 16:55:32 | INFO | run-starfit | Scatter plot of simulation from reservoir 1125
# 2025-04-10 16:55:32 | INFO | run-starfit | Line plot of simulation from reservoir 1125
# 2025-04-10 16:55:32 | INFO | run-starfit | Simulating reservoir 1128
# 2025-04-10 16:55:33 | INFO | run-starfit | Simulation of the calibrated reservoir 1128 successfully finished
# 2025-04-10 16:55:33 | INFO | run-starfit | Performance of reservoir 1128 has been computed
# 2025-04-10 16:55:33 | INFO | run-starfit | Scatter plot of simulation from reservoir 1128
# 2025-04-10 16:55:34 | INFO | run-starfit | Line plot of simulation from reservoir 1128
# 2025-04-10 16:55:34 | INFO | run-starfit | Simulating reservoir 1134
# 2025-04-10 16:55:37 | INFO | run-starfit | Simulation of the calibrated reservoir 1134 successfully finished
# 2025-04-10 16:55:37 | INFO | run-starfit | Performance of reservoir 1134 has been computed
# 2025-04-10 16:55:38 | INFO | run-starfit | Scatter plot of simulation from reservoir 1134
# 2025-04-10 16:55:38 | INFO | run-starfit | Line plot of simulation from reservoir 1134
# 2025-04-10 16:55:38 | INFO | run-starfit | Simulating reservoir 1144
# 2025-04-10 16:55:39 | INFO | run-starfit | Simulation of the calibrated reservoir 1144 successfully finished
# 2025-04-10 16:55:39 | INFO | run-starfit | Performance of reservoir 1144 has been computed
# 2025-04-10 16:55:39 | INFO | run-starfit | Scatter plot of simulation from reservoir 1144
# 2025-04-10 16:55:40 | INFO | run-starfit | Line plot of simulation from reservoir 1144
# 2025-04-10 16:55:40 | INFO | run-starfit | Simulating reservoir 1192
# 2025-04-10 16:55:40 | INFO | run-starfit | Simulation of the calibrated reservoir 1192 successfully finished
# 2025-04-10 16:55:40 | INFO | run-starfit | Performance of reservoir 1192 has been computed
# 2025-04-10 16:55:41 | INFO | run-starfit | Scatter plot of simulation from reservoir 1192
# 2025-04-10 16:55:42 | INFO | run-starfit | Line plot of simulation from reservoir 1192
# 2025-04-10 16:55:42 | INFO | run-starfit | Simulating reservoir 1202
# 2025-04-10 16:55:42 | INFO | run-starfit | Simulation of the calibrated reservoir 1202 successfully finished
# 2025-04-10 16:55:42 | INFO | run-starfit | Performance of reservoir 1202 has been computed
# 2025-04-10 16:55:43 | INFO | run-starfit | Scatter plot of simulation from reservoir 1202
# 2025-04-10 16:55:43 | INFO | run-starfit | Line plot of simulation from reservoir 1202
# 2025-04-10 16:55:43 | INFO | run-starfit | Simulating reservoir 1207
# 2025-04-10 16:55:44 | INFO | run-starfit | Simulation of the calibrated reservoir 1207 successfully finished
# 2025-04-10 16:55:45 | INFO | run-starfit | Performance of reservoir 1207 has been computed
# 2025-04-10 16:55:45 | INFO | run-starfit | Scatter plot of simulation from reservoir 1207
# 2025-04-10 16:55:45 | INFO | run-starfit | Line plot of simulation from reservoir 1207
# 2025-04-10 16:55:45 | INFO | run-starfit | Simulating reservoir 1585
# 2025-04-10 16:55:46 | INFO | run-starfit | Simulation of the calibrated reservoir 1585 successfully finished
# 2025-04-10 16:55:46 | INFO | run-starfit | Performance of reservoir 1585 has been computed
# 2025-04-10 16:55:46 | INFO | run-starfit | Scatter plot of simulation from reservoir 1585
# 2025-04-10 16:55:47 | INFO | run-starfit | Line plot of simulation from reservoir 1585
# 2025-04-10 16:55:47 | INFO | run-starfit | Simulating reservoir 1620
# 2025-04-10 16:55:48 | INFO | run-starfit | Simulation of the calibrated reservoir 1620 successfully finished
# 2025-04-10 16:55:48 | INFO | run-starfit | Performance of reservoir 1620 has been computed
# 2025-04-10 16:55:48 | INFO | run-starfit | Scatter plot of simulation from reservoir 1620
# 2025-04-10 16:55:48 | INFO | run-starfit | Line plot of simulation from reservoir 1620
# 2025-04-10 16:55:48 | INFO | run-starfit | Simulating reservoir 1636
# 2025-04-10 16:55:49 | INFO | run-starfit | Simulation of the calibrated reservoir 1636 successfully finished
# 2025-04-10 16:55:49 | INFO | run-starfit | Performance of reservoir 1636 has been computed
# 2025-04-10 16:55:50 | INFO | run-starfit | Scatter plot of simulation from reservoir 1636
# 2025-04-10 16:55:50 | INFO | run-starfit | Line plot of simulation from reservoir 1636
# 2025-04-10 16:55:50 | INFO | run-starfit | Simulating reservoir 1716
# 2025-04-10 16:55:51 | INFO | run-starfit | Simulation of the calibrated reservoir 1716 successfully finished
# 2025-04-10 16:55:51 | INFO | run-starfit | Performance of reservoir 1716 has been computed
# 2025-04-10 16:55:52 | INFO | run-starfit | Scatter plot of simulation from reservoir 1716
# 2025-04-10 16:55:52 | INFO | run-starfit | Line plot of simulation from reservoir 1716
# 2025-04-10 16:55:52 | INFO | run-starfit | Simulating reservoir 1723
# 2025-04-10 16:55:54 | INFO | run-starfit | Simulation of the calibrated reservoir 1723 successfully finished
# 2025-04-10 16:55:54 | INFO | run-starfit | Performance of reservoir 1723 has been computed
# 2025-04-10 16:55:54 | INFO | run-starfit | Scatter plot of simulation from reservoir 1723
# 2025-04-10 16:55:54 | INFO | run-starfit | Line plot of simulation from reservoir 1723
# 2025-04-10 16:55:54 | INFO | run-starfit | Simulating reservoir 1742
# 2025-04-10 16:55:55 | INFO | run-starfit | Simulation of the calibrated reservoir 1742 successfully finished
# 2025-04-10 16:55:55 | INFO | run-starfit | Performance of reservoir 1742 has been computed
# 2025-04-10 16:55:56 | INFO | run-starfit | Scatter plot of simulation from reservoir 1742
# 2025-04-10 16:55:56 | INFO | run-starfit | Line plot of simulation from reservoir 1742
# 2025-04-10 16:55:56 | INFO | run-starfit | Simulating reservoir 1752
# 2025-04-10 16:55:57 | INFO | run-starfit | Simulation of the calibrated reservoir 1752 successfully finished
# 2025-04-10 16:55:57 | INFO | run-starfit | Performance of reservoir 1752 has been computed
# 2025-04-10 16:55:57 | INFO | run-starfit | Scatter plot of simulation from reservoir 1752
# 2025-04-10 16:55:58 | INFO | run-starfit | Line plot of simulation from reservoir 1752
# 2025-04-10 16:55:58 | INFO | run-starfit | Simulating reservoir 1753
# 2025-04-10 16:56:01 | INFO | run-starfit | Simulation of the calibrated reservoir 1753 successfully finished
# 2025-04-10 16:56:01 | INFO | run-starfit | Performance of reservoir 1753 has been computed
# 2025-04-10 16:56:01 | INFO | run-starfit | Scatter plot of simulation from reservoir 1753
# 2025-04-10 16:56:02 | INFO | run-starfit | Line plot of simulation from reservoir 1753
# 2025-04-10 16:56:02 | INFO | run-starfit | Simulating reservoir 1754
# 2025-04-10 16:56:02 | INFO | run-starfit | Simulation of the calibrated reservoir 1754 successfully finished
# 2025-04-10 16:56:02 | INFO | run-starfit | Performance of reservoir 1754 has been computed
# 2025-04-10 16:56:03 | INFO | run-starfit | Scatter plot of simulation from reservoir 1754
# 2025-04-10 16:56:03 | INFO | run-starfit | Line plot of simulation from reservoir 1754
# 2025-04-10 16:56:03 | INFO | run-starfit | Simulating reservoir 1755
# 2025-04-10 16:56:04 | INFO | run-starfit | Simulation of the calibrated reservoir 1755 successfully finished
# 2025-04-10 16:56:04 | INFO | run-starfit | Performance of reservoir 1755 has been computed
# 2025-04-10 16:56:05 | INFO | run-starfit | Scatter plot of simulation from reservoir 1755
# 2025-04-10 16:56:05 | INFO | run-starfit | Line plot of simulation from reservoir 1755
# 2025-04-10 16:56:05 | INFO | run-starfit | Simulating reservoir 1756
# 2025-04-10 16:56:08 | INFO | run-starfit | Simulation of the calibrated reservoir 1756 successfully finished
# 2025-04-10 16:56:08 | INFO | run-starfit | Performance of reservoir 1756 has been computed
# 2025-04-10 16:56:09 | INFO | run-starfit | Scatter plot of simulation from reservoir 1756
# 2025-04-10 16:56:09 | INFO | run-starfit | Line plot of simulation from reservoir 1756
# 2025-04-10 16:56:09 | INFO | run-starfit | Simulating reservoir 1761
# 2025-04-10 16:56:12 | INFO | run-starfit | Simulation of the calibrated reservoir 1761 successfully finished
# 2025-04-10 16:56:12 | INFO | run-starfit | Performance of reservoir 1761 has been computed
# 2025-04-10 16:56:13 | INFO | run-starfit | Scatter plot of simulation from reservoir 1761
# 2025-04-10 16:56:13 | INFO | run-starfit | Line plot of simulation from reservoir 1761
# 2025-04-10 16:56:13 | INFO | run-starfit | Simulating reservoir 1775
# 2025-04-10 16:56:14 | INFO | run-starfit | Simulation of the calibrated reservoir 1775 successfully finished
# 2025-04-10 16:56:14 | INFO | run-starfit | Performance of reservoir 1775 has been computed
# 2025-04-10 16:56:14 | INFO | run-starfit | Scatter plot of simulation from reservoir 1775
# 2025-04-10 16:56:14 | INFO | run-starfit | Line plot of simulation from reservoir 1775
# 2025-04-10 16:56:14 | INFO | run-starfit | Simulating reservoir 1776
# 2025-04-10 16:56:15 | INFO | run-starfit | Simulation of the calibrated reservoir 1776 successfully finished
# 2025-04-10 16:56:15 | INFO | run-starfit | Performance of reservoir 1776 has been computed
# 2025-04-10 16:56:15 | INFO | run-starfit | Scatter plot of simulation from reservoir 1776
# 2025-04-10 16:56:16 | INFO | run-starfit | Line plot of simulation from reservoir 1776
# 2025-04-10 16:56:16 | INFO | run-starfit | Simulating reservoir 1777
# 2025-04-10 16:56:18 | INFO | run-starfit | Simulation of the calibrated reservoir 1777 successfully finished
# 2025-04-10 16:56:18 | INFO | run-starfit | Performance of reservoir 1777 has been computed
# 2025-04-10 16:56:19 | INFO | run-starfit | Scatter plot of simulation from reservoir 1777
# 2025-04-10 16:56:19 | INFO | run-starfit | Line plot of simulation from reservoir 1777
# 2025-04-10 16:56:19 | INFO | run-starfit | Simulating reservoir 1782
# 2025-04-10 16:56:20 | INFO | run-starfit | Simulation of the calibrated reservoir 1782 successfully finished
# 2025-04-10 16:56:20 | INFO | run-starfit | Performance of reservoir 1782 has been computed
# 2025-04-10 16:56:20 | INFO | run-starfit | Scatter plot of simulation from reservoir 1782
# 2025-04-10 16:56:21 | INFO | run-starfit | Line plot of simulation from reservoir 1782
# 2025-04-10 16:56:21 | INFO | run-starfit | Simulating reservoir 1796
# 2025-04-10 16:56:22 | INFO | run-starfit | Simulation of the calibrated reservoir 1796 successfully finished
# 2025-04-10 16:56:22 | INFO | run-starfit | Performance of reservoir 1796 has been computed
# 2025-04-10 16:56:23 | INFO | run-starfit | Scatter plot of simulation from reservoir 1796
# 2025-04-10 16:56:23 | INFO | run-starfit | Line plot of simulation from reservoir 1796
# 2025-04-10 16:56:23 | INFO | run-starfit | Simulating reservoir 1848
# 2025-04-10 16:56:27 | INFO | run-starfit | Simulation of the calibrated reservoir 1848 successfully finished
# 2025-04-10 16:56:27 | INFO | run-starfit | Performance of reservoir 1848 has been computed
# 2025-04-10 16:56:28 | INFO | run-starfit | Scatter plot of simulation from reservoir 1848
# 2025-04-10 16:56:28 | INFO | run-starfit | Line plot of simulation from reservoir 1848
# 2025-04-10 16:56:28 | INFO | run-starfit | Simulating reservoir 1851
# 2025-04-10 16:56:32 | INFO | run-starfit | Simulation of the calibrated reservoir 1851 successfully finished
# 2025-04-10 16:56:32 | INFO | run-starfit | Performance of reservoir 1851 has been computed
# 2025-04-10 16:56:33 | INFO | run-starfit | Scatter plot of simulation from reservoir 1851
# 2025-04-10 16:56:34 | INFO | run-starfit | Line plot of simulation from reservoir 1851
# 2025-04-10 16:56:34 | INFO | run-starfit | Simulating reservoir 1864
# 2025-04-10 16:56:36 | INFO | run-starfit | Simulation of the calibrated reservoir 1864 successfully finished
# 2025-04-10 16:56:36 | INFO | run-starfit | Performance of reservoir 1864 has been computed
# 2025-04-10 16:56:36 | INFO | run-starfit | Scatter plot of simulation from reservoir 1864
# 2025-04-10 16:56:37 | INFO | run-starfit | Line plot of simulation from reservoir 1864
# 2025-04-10 16:56:37 | INFO | run-starfit | Simulating reservoir 1869
# 2025-04-10 16:56:38 | INFO | run-starfit | Simulation of the calibrated reservoir 1869 successfully finished
# 2025-04-10 16:56:38 | INFO | run-starfit | Performance of reservoir 1869 has been computed
# 2025-04-10 16:56:39 | INFO | run-starfit | Scatter plot of simulation from reservoir 1869
# 2025-04-10 16:56:39 | INFO | run-starfit | Line plot of simulation from reservoir 1869
# 2025-04-10 16:56:39 | INFO | run-starfit | Simulating reservoir 1872
# 2025-04-10 16:56:42 | INFO | run-starfit | Simulation of the calibrated reservoir 1872 successfully finished
# 2025-04-10 16:56:42 | INFO | run-starfit | Performance of reservoir 1872 has been computed
# 2025-04-10 16:56:43 | INFO | run-starfit | Scatter plot of simulation from reservoir 1872
# 2025-04-10 16:56:44 | INFO | run-starfit | Line plot of simulation from reservoir 1872
# 2025-04-10 16:56:44 | INFO | run-starfit | Simulating reservoir 1910
# 2025-04-10 16:56:45 | INFO | run-starfit | Simulation of the calibrated reservoir 1910 successfully finished
# 2025-04-10 16:56:45 | INFO | run-starfit | Performance of reservoir 1910 has been computed
# 2025-04-10 16:56:45 | INFO | run-starfit | Scatter plot of simulation from reservoir 1910
# 2025-04-10 16:56:46 | INFO | run-starfit | Line plot of simulation from reservoir 1910
# 2025-04-10 16:56:46 | INFO | run-starfit | Simulating reservoir 7308
# 2025-04-10 16:56:49 | INFO | run-starfit | Simulation of the calibrated reservoir 7308 successfully finished
# 2025-04-10 16:56:49 | INFO | run-starfit | Performance of reservoir 7308 has been computed
# 2025-04-10 16:56:50 | INFO | run-starfit | Scatter plot of simulation from reservoir 7308
# 2025-04-10 16:56:50 | INFO | run-starfit | Line plot of simulation from reservoir 7308
# 2025-04-10 16:56:50 | INFO | run-starfit | Simulating reservoir 7313
# 2025-04-10 16:56:54 | INFO | run-starfit | Simulation of the calibrated reservoir 7313 successfully finished
# 2025-04-10 16:56:54 | INFO | run-starfit | Performance of reservoir 7313 has been computed
# 2025-04-10 16:56:55 | INFO | run-starfit | Scatter plot of simulation from reservoir 7313
# 2025-04-10 16:56:56 | INFO | run-starfit | Line plot of simulation from reservoir 7313
