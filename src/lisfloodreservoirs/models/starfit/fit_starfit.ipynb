# %%
import numpy as np
import pandas as pd
# from pathlib import Path
from tqdm.auto import tqdm
# import matplotlib.pyplot as plt
import pickle
import logging

from storage import fit_storage, create_storage_harmonic
from release import fit_release, create_release_harmonic, create_release_linear
from inputs import read_reservoir_attributes, read_reservoir_data#, rank_and_filter_data
from functions import plot_nor, plot_release, epiweek_to_date

# from lisfloodreservoirs.utils.metrics import KGEmod
from lisfloodreservoirs import Config, read_attributes, read_timeseries

# %% [markdown]
# ## Configuration

# %%
config_file = 'Z:/nahaUsers/casadje/datasets/reservoirs/ResOpsUS/v2.0/results/starfit/config.yml'
cfg = Config(config_file)

# %% [markdown]
# ### Logger

# %%
# set up root logger
root_logger = logging.getLogger()
root_logger.setLevel(logging.INFO)

# define format
log_format = logging.Formatter('%(asctime)s | %(levelname)s | %(name)s | %(message)s',
                               datefmt='%Y-%m-%d %H:%M:%S')

# # define log file
# log_path = cfg.PATH_CALIB / 'logs'
# log_path.mkdir(exist_ok=True)
# log_file = log_path / '{0:%Y%m%d%H%M}_calibrate_{1}.log'.format(
#     datetime.now(),
#     '_'.join(config_file.split('.')[0].split('_')[1:]))

# prevent duplicate logs in Jupyter or re-runs
if not root_logger.handlers:
    # console handler
    c_handler = logging.StreamHandler()
    c_handler.setFormatter(log_format)
    root_logger.addHandler(c_handler)

    # # file handler
    # f_handler = logging.FileHandler(log_file)
    # f_handler.setFormatter(log_format)
    # root_logger.addHandler(f_handler)

# Optional: create a named logger for this script
logger = logging.getLogger('fit-starfit')

# %%
PATH_STORAGE = cfg.PATH_DEF.parent / 'NOR'
PATH_STORAGE.mkdir(parents=True, exist_ok=True)
logger.info(f'Storage fitted parameters will be saved in: {PATH_STORAGE}')

PATH_RELEASE = cfg.PATH_DEF.parent / 'release'
PATH_RELEASE.mkdir(parents=True, exist_ok=True)
logger.info(f'Release fitted parameters will be saved in: {PATH_RELEASE}')
# Out:
# 2025-04-10 13:24:30 | INFO | fit-starfit | Storage fitted parameters will be saved in: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsUS\v2.0\results\starfit\NOR
# 2025-04-10 13:24:30 | INFO | fit-starfit | Release fitted parameters will be saved in: Z:\nahaUsers\casadje\datasets\reservoirs\ResOpsUS\v2.0\results\starfit\release

# %% [markdown]
# ## Data

# %% [markdown]
# ### Attributes

# %%
# list of reservoirs to be trained
try:
    reservoirs = pd.read_csv(cfg.RESERVOIRS_FILE, header=None).squeeze().tolist()
except IOError as e:
    logger.error(f'Failed to open {cfg.RESERVOIRS_FILE}: {e}')
    raise

# import all tables of attributes
try:
    attributes = read_attributes(cfg.PATH_DATA / 'attributes', reservoirs)
except IOError as e:
    logger.error('Failed to read attribute tables from {0}: {1}'.format(cfg.PATH_DATA / 'attributes', e))
    raise
logger.info(f'{attributes.shape[0]} reservoirs in the attribute tables')
# Out:
# 2025-04-10 13:24:30 | INFO | fit-starfit | 123 reservoirs in the attribute tables

# %% [markdown]
# ### Time series

# %%
from datetime import datetime

# %%
log_file = 'asdf.log'

# %%
if log_file is not None:
    print('hola')
# Out:
# hola

# %%
# training periods
try:
    with open(cfg.PERIODS_FILE, 'rb') as file:
        periods = pickle.load(file)
except IOError as e:
    logger.error(f'Failed to open {cfg.PERIODS_FILE}: {e}')
    raise

# read time series
try:
    timeseries = read_timeseries(
        cfg.PATH_DATA / 'time_series' / 'csv',
        attributes.index,
        periods
    )
    for grand_id, obs in timeseries.items():
        obs['s'] = obs.storage * 1e-6 # MCM
        obs[['i', 'r']] = obs[['inflow', 'outflow']] * 1e-6 * 86400 # MCM/day
except IOError as e:
    logger.error('Failed to read time series from {0}: {1}'.format(cfg.PATH_DATA / 'time_series' / 'csv', e))
    raise
logger.info(f'{len(timeseries)} reservoirs with timeseries')
# Out:
# 2025-04-10 13:24:54 | INFO | fit-starfit | 123 reservoirs with timeseries

# %% [markdown]
# ## Fit reservoir
#
# ### Storage functions

# %%
for grand_id, obs in tqdm(timeseries.items()):
        
    # update reservoir capacity, if maximum observeation exceeds GRanD
    attributes.loc[grand_id, 'CAP_MCM'] = max(attributes.loc[grand_id, 'CAP_MCM'], obs.s.max())

    # fit storage model
    for years, n_points in zip([8, 6, 4], [3, 2, 2]):
        model_storage = fit_storage(
            grand_id, 
            storage_daily=obs.s, 
            attributes=attributes.loc[grand_id],
            min_days=years * 365,
            n_points=n_points,
        )
        if not model_storage['weekly storage'].empty:
            break

    if model_storage['weekly storage'].empty:
        logger.warning(f'The normal operating rules could not be fitted')
        continue

    # export fitted parameters
    pars_to_export = ['capacity (MCM)', 'NOR upper bound', 'NOR lower bound']
    pars = {key: value for key, value in model_storage.items() if key in pars_to_export}
    with open(PATH_STORAGE / f'{grand_id}.pkl', 'wb') as file:
             pickle.dump(pars, file)
    # pd.DataFrame({
    #             'flood': model_storage["NOR upper bound"],
    #             'conservation': model_storage["NOR lower bound"]
    #         }).to_csv(PATH_STORAGE / f'{grand_id}.csv', index=False)
    
    # define normal operating range (NOR)
    NORup = create_storage_harmonic(model_storage['NOR upper bound'], name='flood').set_index('epiweek')
    NORdown = create_storage_harmonic(model_storage['NOR lower bound'], name='conservation').set_index('epiweek')
    NOR = pd.concat((NORup, NORdown), axis=1)

    # weekly time series of standardised storage combined with NOR
    weekly_storage = model_storage['weekly storage']

    # plot model
    plot_nor(
        weekly_storage,
        NOR,
        n_points=n_points,
        title='{0} - {1}'.format(grand_id, attributes.loc[grand_id, 'DAM_NAME']),
        save=PATH_STORAGE / f'{grand_id}.jpg'
    )
# Out:
#   0%|          | 0/123 [00:00<?, ?it/s]
# 2025-04-10 12:00:25 | INFO | storage | Fitting targets for dam 41: Ross
# 2025-04-10 12:00:25 | INFO | storage | Cutoff year set back to 1999
# 2025-04-10 12:00:25 | INFO | storage | Fitting targets for dam 63: Tieton
# 2025-04-10 12:00:25 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:26 | INFO | storage | Fitting targets for dam 131: Trinity
# 2025-04-10 12:00:26 | WARNING | storage | Number of days with storage data (2225) smaller than the minimum (2920)
# 2025-04-10 12:00:26 | INFO | storage | Fitting targets for dam 131: Trinity
# 2025-04-10 12:00:26 | INFO | storage | Cutoff year set back to 1998
# 2025-04-10 12:00:27 | INFO | storage | Fitting targets for dam 132: Shasta
# 2025-04-10 12:00:27 | WARNING | storage | Number of days with storage data (1865) smaller than the minimum (2920)
# 2025-04-10 12:00:27 | INFO | storage | Fitting targets for dam 132: Shasta
# 2025-04-10 12:00:27 | WARNING | storage | Number of days with storage data (1865) smaller than the minimum (2190)
# 2025-04-10 12:00:27 | INFO | storage | Fitting targets for dam 132: Shasta
# 2025-04-10 12:00:27 | INFO | storage | Cutoff year set back to 2013
# 2025-04-10 12:00:27 | INFO | storage | Fitting targets for dam 133: Whiskeytown
# 2025-04-10 12:00:27 | WARNING | storage | Number of days with storage data (1858) smaller than the minimum (2920)
# 2025-04-10 12:00:27 | INFO | storage | Fitting targets for dam 133: Whiskeytown
# 2025-04-10 12:00:27 | WARNING | storage | Number of days with storage data (1858) smaller than the minimum (2190)
# 2025-04-10 12:00:27 | INFO | storage | Fitting targets for dam 133: Whiskeytown
# 2025-04-10 12:00:27 | INFO | storage | Cutoff year set back to 2013
# 2025-04-10 12:00:27 | INFO | storage | Fitting targets for dam 182: Folsom
# 2025-04-10 12:00:27 | WARNING | storage | Number of days with storage data (1565) smaller than the minimum (2920)
# 2025-04-10 12:00:27 | INFO | storage | Fitting targets for dam 182: Folsom
# 2025-04-10 12:00:27 | WARNING | storage | Number of days with storage data (1565) smaller than the minimum (2190)
# 2025-04-10 12:00:27 | INFO | storage | Fitting targets for dam 182: Folsom
# 2025-04-10 12:00:27 | INFO | storage | Cutoff year set back to 2000
# 2025-04-10 12:00:28 | INFO | storage | Fitting targets for dam 198: New Melones
# 2025-04-10 12:00:28 | WARNING | storage | Number of days with storage data (2221) smaller than the minimum (2920)
# 2025-04-10 12:00:28 | INFO | storage | Fitting targets for dam 198: New Melones
# 2025-04-10 12:00:28 | INFO | storage | Cutoff year set back to 2013
# 2025-04-10 12:00:28 | INFO | storage | Fitting targets for dam 293: Fresno
# 2025-04-10 12:00:28 | INFO | storage | Cutoff year set back to 1989
# 2025-04-10 12:00:28 | INFO | storage | Fitting targets for dam 297: Libby
# 2025-04-10 12:00:28 | WARNING | storage | Number of days with storage data (1636) smaller than the minimum (2920)
# 2025-04-10 12:00:28 | INFO | storage | Fitting targets for dam 297: Libby
# 2025-04-10 12:00:28 | WARNING | storage | Number of days with storage data (1636) smaller than the minimum (2190)
# 2025-04-10 12:00:28 | INFO | storage | Fitting targets for dam 297: Libby
# 2025-04-10 12:00:28 | INFO | storage | Cutoff year set back to 2008
# 2025-04-10 12:00:29 | INFO | storage | Fitting targets for dam 300: Tiber Dike
# 2025-04-10 12:00:29 | INFO | storage | Cutoff year set back to 2007
# 2025-04-10 12:00:29 | INFO | storage | Fitting targets for dam 307: Fort Peck Dam
# 2025-04-10 12:00:29 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:29 | INFO | storage | Fitting targets for dam 319: Gibson
# 2025-04-10 12:00:29 | INFO | storage | Cutoff year set back to 1994
# 2025-04-10 12:00:30 | INFO | storage | Fitting targets for dam 355: Yellowtail
# 2025-04-10 12:00:30 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:30 | INFO | storage | Fitting targets for dam 361: Thief Valley
# 2025-04-10 12:00:30 | WARNING | storage | Number of days with storage data (2005) smaller than the minimum (2920)
# 2025-04-10 12:00:30 | INFO | storage | Fitting targets for dam 361: Thief Valley
# 2025-04-10 12:00:30 | WARNING | storage | Number of days with storage data (2005) smaller than the minimum (2190)
# 2025-04-10 12:00:30 | INFO | storage | Fitting targets for dam 361: Thief Valley
# 2025-04-10 12:00:30 | INFO | storage | Cutoff year set back to 1997
# 2025-04-10 12:00:31 | INFO | storage | Fitting targets for dam 362: Clark Canyon
# 2025-04-10 12:00:31 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:32 | INFO | storage | Fitting targets for dam 364: Hebgen Dam
# 2025-04-10 12:00:32 | INFO | storage | Cutoff year set back to 1995
# 2025-04-10 12:00:33 | INFO | storage | Fitting targets for dam 367: Mason
# 2025-04-10 12:00:33 | INFO | storage | Cutoff year set back to 1997
# 2025-04-10 12:00:33 | INFO | storage | Fitting targets for dam 368: Lima
# 2025-04-10 12:00:33 | INFO | storage | Cutoff year set back to 2007
# 2025-04-10 12:00:33 | INFO | storage | Fitting targets for dam 372: Unity
# 2025-04-10 12:00:33 | INFO | storage | Cutoff year set back to 1994
# 2025-04-10 12:00:34 | INFO | storage | Fitting targets for dam 373: Buffalo Bill
# 2025-04-10 12:00:34 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:34 | INFO | storage | Fitting targets for dam 384: Jackson Lake
# 2025-04-10 12:00:34 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:35 | INFO | storage | Fitting targets for dam 390: Ririe
# 2025-04-10 12:00:35 | WARNING | storage | Number of days with storage data (2349) smaller than the minimum (2920)
# 2025-04-10 12:00:35 | INFO | storage | Fitting targets for dam 390: Ririe
# 2025-04-10 12:00:35 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:35 | INFO | storage | Fitting targets for dam 391: Lucky Peak
# 2025-04-10 12:00:35 | INFO | storage | Cutoff year set back to 2004
# 2025-04-10 12:00:36 | INFO | storage | Fitting targets for dam 393: Boysen
# 2025-04-10 12:00:36 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:37 | INFO | storage | Fitting targets for dam 398: Bull Lake
# 2025-04-10 12:00:37 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:37 | INFO | storage | Fitting targets for dam 416: Pathfinder Dike
# 2025-04-10 12:00:37 | INFO | storage | Cutoff year set back to 1993
# 2025-04-10 12:00:38 | INFO | storage | Fitting targets for dam 419: Big Sandy Dike
# 2025-04-10 12:00:38 | INFO | storage | Cutoff year set back to 2009
# 2025-04-10 12:00:38 | INFO | storage | Fitting targets for dam 421: Seminoe
# 2025-04-10 12:00:38 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:38 | INFO | storage | Fitting targets for dam 423: Fontenelle
# 2025-04-10 12:00:38 | INFO | storage | Cutoff year set back to 1988
# 2025-04-10 12:00:39 | INFO | storage | Fitting targets for dam 431: Hyrum
# 2025-04-10 12:00:39 | WARNING | storage | Number of days with storage data (1516) smaller than the minimum (2920)
# 2025-04-10 12:00:39 | INFO | storage | Fitting targets for dam 431: Hyrum
# 2025-04-10 12:00:39 | WARNING | storage | Number of days with storage data (1516) smaller than the minimum (2190)
# 2025-04-10 12:00:39 | INFO | storage | Fitting targets for dam 431: Hyrum
# 2025-04-10 12:00:39 | INFO | storage | Cutoff year set back to 2015
# 2025-04-10 12:00:39 | INFO | storage | Fitting targets for dam 438: Pineview
# 2025-04-10 12:00:39 | INFO | storage | Cutoff year set back to 2008
# 2025-04-10 12:00:40 | INFO | storage | Fitting targets for dam 442: Lost Creek
# 2025-04-10 12:00:40 | INFO | storage | Cutoff year set back to 1998
# 2025-04-10 12:00:40 | INFO | storage | Fitting targets for dam 445: Meeks Cabin
# 2025-04-10 12:00:40 | INFO | storage | Cutoff year set back to 2001
# 2025-04-10 12:00:41 | INFO | storage | Fitting targets for dam 449: Echo
# 2025-04-10 12:00:41 | INFO | storage | Cutoff year set back to 1990
# 2025-04-10 12:00:41 | INFO | storage | Fitting targets for dam 450: East Canyon
# 2025-04-10 12:00:41 | WARNING | storage | Number of days with storage data (2146) smaller than the minimum (2920)
# 2025-04-10 12:00:41 | INFO | storage | Fitting targets for dam 450: East Canyon
# 2025-04-10 12:00:41 | WARNING | storage | Number of days with storage data (2146) smaller than the minimum (2190)
# 2025-04-10 12:00:41 | INFO | storage | Fitting targets for dam 450: East Canyon
# 2025-04-10 12:00:41 | INFO | storage | Cutoff year set back to 2003
# 2025-04-10 12:00:41 | INFO | storage | Fitting targets for dam 451: Flaming Gorge
# 2025-04-10 12:00:41 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:42 | INFO | storage | Fitting targets for dam 456: Wanship
# 2025-04-10 12:00:42 | INFO | storage | Cutoff year set back to 1987
# 2025-04-10 12:00:43 | INFO | storage | Fitting targets for dam 467: Bor Jordanelle
# 2025-04-10 12:00:43 | INFO | storage | Cutoff year set back to 1993
# 2025-04-10 12:00:43 | INFO | storage | Fitting targets for dam 471: Moon Lake
# 2025-04-10 12:00:43 | INFO | storage | Cutoff year set back to 2007
# 2025-04-10 12:00:43 | INFO | storage | Fitting targets for dam 477: Deer Creek
# 2025-04-10 12:00:43 | INFO | storage | Cutoff year set back to 1986
# 2025-04-10 12:00:44 | INFO | storage | Fitting targets for dam 488: Bor Starvation
# 2025-04-10 12:00:44 | INFO | storage | Cutoff year set back to 1997
# 2025-04-10 12:00:44 | INFO | storage | Fitting targets for dam 497: Williams Fork
# 2025-04-10 12:00:44 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:45 | INFO | storage | Fitting targets for dam 502: Green Mountain
# 2025-04-10 12:00:45 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:46 | INFO | storage | Fitting targets for dam 506: Scofield
# 2025-04-10 12:00:46 | WARNING | storage | Number of days with storage data (1933) smaller than the minimum (2920)
# 2025-04-10 12:00:46 | INFO | storage | Fitting targets for dam 506: Scofield
# 2025-04-10 12:00:46 | WARNING | storage | Number of days with storage data (1933) smaller than the minimum (2190)
# 2025-04-10 12:00:46 | INFO | storage | Fitting targets for dam 506: Scofield
# 2025-04-10 12:00:46 | INFO | storage | Cutoff year set back to 2008
# 2025-04-10 12:00:46 | INFO | storage | Fitting targets for dam 507: Rifle Gap
# 2025-04-10 12:00:46 | WARNING | storage | Number of days with storage data (1948) smaller than the minimum (2920)
# 2025-04-10 12:00:46 | INFO | storage | Fitting targets for dam 507: Rifle Gap
# 2025-04-10 12:00:46 | WARNING | storage | Number of days with storage data (1948) smaller than the minimum (2190)
# 2025-04-10 12:00:46 | INFO | storage | Fitting targets for dam 507: Rifle Gap
# 2025-04-10 12:00:46 | INFO | storage | Cutoff year set back to 2012
# 2025-04-10 12:00:46 | INFO | storage | Fitting targets for dam 511: Chatfield Dam
# 2025-04-10 12:00:46 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:47 | INFO | storage | Fitting targets for dam 517: Ruedi
# 2025-04-10 12:00:47 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:47 | INFO | storage | Fitting targets for dam 518: Joes Valley
# 2025-04-10 12:00:47 | INFO | storage | Cutoff year set back to 2004
# 2025-04-10 12:00:48 | INFO | storage | Fitting targets for dam 522: Cheesman
# 2025-04-10 12:00:48 | INFO | storage | Cutoff year set back to 1999
# 2025-04-10 12:00:48 | INFO | storage | Fitting targets for dam 529: Antero
# 2025-04-10 12:00:48 | WARNING | storage | Number of days with storage data (2376) smaller than the minimum (2920)
# 2025-04-10 12:00:48 | INFO | storage | Fitting targets for dam 529: Antero
# 2025-04-10 12:00:48 | INFO | storage | Cutoff year set back to 1986
# 2025-04-10 12:00:48 | INFO | storage | Fitting targets for dam 530: Spinney Mountain
# 2025-04-10 12:00:48 | INFO | storage | Cutoff year set back to 1990
# 2025-04-10 12:00:49 | INFO | storage | Fitting targets for dam 531: Paonia
# 2025-04-10 12:00:49 | WARNING | storage | Number of days with storage data (1794) smaller than the minimum (2920)
# 2025-04-10 12:00:49 | INFO | storage | Fitting targets for dam 531: Paonia
# 2025-04-10 12:00:49 | WARNING | storage | Number of days with storage data (1794) smaller than the minimum (2190)
# 2025-04-10 12:00:49 | INFO | storage | Fitting targets for dam 531: Paonia
# 2025-04-10 12:00:49 | INFO | storage | Cutoff year set back to 2000
# 2025-04-10 12:00:49 | INFO | storage | Fitting targets for dam 533: Eleven Mile Canyon
# 2025-04-10 12:00:49 | INFO | storage | Cutoff year set back to 1997
# 2025-04-10 12:00:50 | INFO | storage | Fitting targets for dam 536: Taylor Park
# 2025-04-10 12:00:50 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:50 | INFO | storage | Fitting targets for dam 541: Blue Mesa
# 2025-04-10 12:00:50 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:51 | INFO | storage | Fitting targets for dam 575: Vallecito
# 2025-04-10 12:00:51 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:51 | INFO | storage | Fitting targets for dam 595: Friant
# 2025-04-10 12:00:51 | INFO | storage | Cutoff year set back to 2000
# 2025-04-10 12:00:52 | INFO | storage | Fitting targets for dam 597: Glen Canyon
# 2025-04-10 12:00:52 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:52 | INFO | storage | Fitting targets for dam 601: Navajo
# 2025-04-10 12:00:52 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:53 | INFO | storage | Fitting targets for dam 657: Elephant Butte Dike
# 2025-04-10 12:00:53 | WARNING | storage | Number of days with storage data (2799) smaller than the minimum (2920)
# 2025-04-10 12:00:53 | INFO | storage | Fitting targets for dam 657: Elephant Butte Dike
# 2025-04-10 12:00:53 | INFO | storage | Cutoff year set back to 2005
# 2025-04-10 12:00:53 | INFO | storage | Fitting targets for dam 753: Garrison Dam
# 2025-04-10 12:00:53 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:54 | INFO | storage | Fitting targets for dam 780: Jamestown
# 2025-04-10 12:00:54 | INFO | storage | Cutoff year set back to 2006
# 2025-04-10 12:00:54 | INFO | storage | Fitting targets for dam 789: Sandy Lake Dam and Lock
# 2025-04-10 12:00:54 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:55 | INFO | storage | Fitting targets for dam 868: Belle Fourche
# 2025-04-10 12:00:55 | WARNING | storage | Number of days with storage data (2124) smaller than the minimum (2920)
# 2025-04-10 12:00:55 | INFO | storage | Fitting targets for dam 868: Belle Fourche
# 2025-04-10 12:00:55 | WARNING | storage | Number of days with storage data (2124) smaller than the minimum (2190)
# 2025-04-10 12:00:55 | INFO | storage | Fitting targets for dam 868: Belle Fourche
# 2025-04-10 12:00:55 | INFO | storage | Cutoff year set back to 2010
# 2025-04-10 12:00:55 | INFO | storage | Fitting targets for dam 870: Oahe Dam
# 2025-04-10 12:00:55 | INFO | storage | Cutoff year set back to 2010
# 2025-04-10 12:00:56 | INFO | storage | Fitting targets for dam 882: Pactola
# 2025-04-10 12:00:56 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:56 | INFO | storage | Fitting targets for dam 893: Angostura
# 2025-04-10 12:00:56 | WARNING | storage | Number of days with storage data (1949) smaller than the minimum (2920)
# 2025-04-10 12:00:56 | INFO | storage | Fitting targets for dam 893: Angostura
# 2025-04-10 12:00:56 | WARNING | storage | Number of days with storage data (1949) smaller than the minimum (2190)
# 2025-04-10 12:00:56 | INFO | storage | Fitting targets for dam 893: Angostura
# 2025-04-10 12:00:56 | INFO | storage | Cutoff year set back to 2013
# 2025-04-10 12:00:57 | INFO | storage | Fitting targets for dam 898: Glendo
# 2025-04-10 12:00:57 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:57 | INFO | storage | Fitting targets for dam 938: Medicine Creek
# 2025-04-10 12:00:57 | WARNING | storage | Number of days with storage data (2754) smaller than the minimum (2920)
# 2025-04-10 12:00:57 | INFO | storage | Fitting targets for dam 938: Medicine Creek
# 2025-04-10 12:00:57 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:58 | INFO | storage | Fitting targets for dam 952: Lovewell
# 2025-04-10 12:00:58 | INFO | storage | Cutoff year set back to 2010
# 2025-04-10 12:00:58 | INFO | storage | Fitting targets for dam 957: Cherry Creek Dam
# 2025-04-10 12:00:58 | INFO | storage | Cutoff year set back to 1984
# 2025-04-10 12:00:58 | INFO | storage | Fitting targets for dam 982: Melvern Dam
# 2025-04-10 12:00:58 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:59 | INFO | storage | Fitting targets for dam 987: Pueblo
# 2025-04-10 12:00:59 | INFO | storage | Cutoff year set back to 1984
# 2025-04-10 12:00:59 | INFO | storage | Fitting targets for dam 989: Harry S. Truman Dam
# 2025-04-10 12:00:59 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:00:59 | INFO | storage | Fitting targets for dam 1006: Stockton Dam
# 2025-04-10 12:00:59 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:01:00 | INFO | storage | Fitting targets for dam 1020: Copan Lake
# 2025-04-10 12:01:00 | WARNING | storage | Number of days with storage data (2107) smaller than the minimum (2920)
# 2025-04-10 12:01:00 | INFO | storage | Fitting targets for dam 1020: Copan Lake
# 2025-04-10 12:01:00 | WARNING | storage | Number of days with storage data (2107) smaller than the minimum (2190)
# 2025-04-10 12:01:00 | INFO | storage | Fitting targets for dam 1020: Copan Lake
# 2025-04-10 12:01:00 | INFO | storage | Cutoff year set back to 1986
# 2025-04-10 12:01:00 | INFO | storage | Fitting targets for dam 1023: Kaw Lake
# 2025-04-10 12:01:00 | INFO | storage | Cutoff year set back to 1991
# 2025-04-10 12:01:00 | INFO | storage | Fitting targets for dam 1026: Table Rock Dam
# 2025-04-10 12:01:00 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12
# 2025-04-10 12:01:12 | INFO | storage | Fitting targets for dam 1752: Barkley Dam
# 2025-04-10 12:01:12 | WARNING | storage | Number of days with storage data (2635) smaller than the minimum (2920)
# 2025-04-10 12:01:12 | INFO | storage | Fitting targets for dam 1752: Barkley Dam
# 2025-04-10 12:01:12 | INFO | storage | Cutoff year set back to 1987
# 2025-04-10 12:01:12 | INFO | storage | Fitting targets for dam 1753: Kentucky
# 2025-04-10 12:01:12 | INFO | storage | Cutoff year set back to 1991
# 2025-04-10 12:01:12 | INFO | storage | Fitting targets for dam 1754: Laurel Dam
# 2025-04-10 12:01:12 | WARNING | storage | Number of days with storage data (2145) smaller than the minimum (2920)
# 2025-04-10 12:01:12 | INFO | storage | Fitting targets for dam 1754: Laurel Dam
# 2025-04-10 12:01:12 | WARNING | storage | Number of days with storage data (2145) smaller than the minimum (2190)
# 2025-04-10 12:01:12 | INFO | storage | Fitting targets for dam 1754: Laurel Dam
# 2025-04-10 12:01:12 | INFO | storage | Cutoff year set back to 1987
# 2025-04-10 12:01:13 | INFO | storage | Fitting targets for dam 1755: Barren River Lake Dam
# 2025-04-10 12:01:13 | INFO | storage | Cutoff year set back to 2001
# 2025-04-10 12:01:13 | INFO | storage | Fitting targets for dam 1756: Wolf Creek
# 2025-04-10 12:01:13 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:01:13 | INFO | storage | Fitting targets for dam 1761: John H. Kerr Dam
# 2025-04-10 12:01:13 | INFO | storage | Cutoff year set back to 1995
# 2025-04-10 12:01:14 | INFO | storage | Fitting targets for dam 1775: J. Percy Priest Dam
# 2025-04-10 12:01:14 | WARNING | storage | Number of days with storage data (1824) smaller than the minimum (2920)
# 2025-04-10 12:01:14 | INFO | storage | Fitting targets for dam 1775: J. Percy Priest Dam
# 2025-04-10 12:01:14 | WARNING | storage | Number of days with storage data (1824) smaller than the minimum (2190)
# 2025-04-10 12:01:14 | INFO | storage | Fitting targets for dam 1775: J. Percy Priest Dam
# 2025-04-10 12:01:14 | INFO | storage | Cutoff year set back to 1990
# 2025-04-10 12:01:14 | INFO | storage | Fitting targets for dam 1776: W. Kerr Scott Dam
# 2025-04-10 12:01:14 | WARNING | storage | Number of days with storage data (1539) smaller than the minimum (2920)
# 2025-04-10 12:01:14 | INFO | storage | Fitting targets for dam 1776: W. Kerr Scott Dam
# 2025-04-10 12:01:14 | WARNING | storage | Number of days with storage data (1539) smaller than the minimum (2190)
# 2025-04-10 12:01:14 | INFO | storage | Fitting targets for dam 1776: W. Kerr Scott Dam
# 2025-04-10 12:01:14 | INFO | storage | Cutoff year set back to 1998
# 2025-04-10 12:01:15 | INFO | storage | Fitting targets for dam 1777: Center Hill Dam
# 2025-04-10 12:01:15 | INFO | storage | Cutoff year set back to 1995
# 2025-04-10 12:01:15 | INFO | storage | Fitting targets for dam 1782: Falls Lake Dam
# 2025-04-10 12:01:15 | WARNING | storage | Number of days with storage data (1594) smaller than the minimum (2920)
# 2025-04-10 12:01:15 | INFO | storage | Fitting targets for dam 1782: Falls Lake Dam
# 2025-04-10 12:01:15 | WARNING | storage | Number of days with storage data (1594) smaller than the minimum (2190)
# 2025-04-10 12:01:15 | INFO | storage | Fitting targets for dam 1782: Falls Lake Dam
# 2025-04-10 12:01:15 | INFO | storage | Cutoff year set back to 1993
# 2025-04-10 12:01:15 | INFO | storage | Fitting targets for dam 1796: B. Everett Jordan Dam
# 2025-04-10 12:01:15 | INFO | storage | Cutoff year set back to 2005
# 2025-04-10 12:01:16 | INFO | storage | Fitting targets for dam 1848: Sardis Dam
# 2025-04-10 12:01:16 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:01:16 | INFO | storage | Fitting targets for dam 1851: Hartwell Dam
# 2025-04-10 12:01:16 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:01:17 | INFO | storage | Fitting targets for dam 1864: Enid Dam
# 2025-04-10 12:01:17 | INFO | storage | Cutoff year set back to 1999
# 2025-04-10 12:01:17 | INFO | storage | Fitting targets for dam 1869: Grenada Dam
# 2025-04-10 12:01:17 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:01:17 | INFO | storage | Fitting targets for dam 1872: J. Strom Thurmond Dam
# 2025-04-10 12:01:17 | INFO | storage | Cutoff year set back to 1990
# 2025-04-10 12:01:18 | INFO | storage | Fitting targets for dam 1910: Walter F. George Lock and Dam
# 2025-04-10 12:01:18 | INFO | storage | Cutoff year set back to 1982
# 2025-04-10 12:01:18 | INFO | storage | Fitting targets for dam 7308: Richard B. Russell Dam
# 2025-04-10 12:01:18 | INFO | storage | Cutoff year set back to 1987
# 2025-04-10 12:01:18 | INFO | storage | Fitting targets for dam 7313: Canyon Ferry Dam
# 2025-04-10 12:01:18 | INFO | storage | Cutoff year set back to 1982

# %% [markdown]
# ### Release function

# %%
ids = [int(file.stem) for file in PATH_STORAGE.glob('*.pkl')]
for grand_id in tqdm(ids):

    obs = timeseries[grand_id]
    
    # update reservoir capacity, if maximum observeation exceeds GRanD
    attributes.loc[grand_id, 'CAP_MCM'] = max(attributes.loc[grand_id, 'CAP_MCM'], obs.s.max())

    # fit release model
    for years in [5, 4]:
        model_release = fit_release(
            grand_id,
            daily_ops=obs[['s', 'i', 'r']],
            attributes=attributes.loc[grand_id],
            NOR_path=PATH_STORAGE,
            cutoff_year=None,
            min_weeks=52 * years
        )
        if pd.notna(model_release['mean inflow (MCM/wk)']):
            break

    if not model_release or all(np.isnan(model_release['harmonic parameters'])):
        logger.warning(f'The relase model for reservoir {grand_id} could not be fitted')
        continue

    # export fitted parameters
    pars_to_export = ['mean inflow (MCM/wk)', 'harmonic parameters', 'residual parameters', 'constraints']
    pars = {key: value for key, value in model_release.items() if key in pars_to_export}
    with open(PATH_RELEASE / f'{grand_id}.pkl', 'wb') as file:
             pickle.dump(pars, file)

    # extract info from the fitted release: average inflow, harmonic release (standardised) and release contraints
    avg_inflow = model_release['mean inflow (MCM/wk)']
    release_harmonic = create_release_harmonic(model_release['harmonic parameters']).set_index('epiweek').squeeze()
    release_linear = create_release_linear(model_release['residual parameters'])
    Qmin, Qmax = model_release['constraints']
    weekly_release = model_release['weekly release'].set_index('epiweek')

    # plot model
    title = '{0} - {1}'.format(grand_id, attributes.loc[grand_id, 'DAM_NAME'])
